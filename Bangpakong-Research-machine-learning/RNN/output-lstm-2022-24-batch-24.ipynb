# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'Angsana New'
rcParams.update({'font.size': 22})
rcParams['axes.unicode_minus'] = False

# %%
# df_read = pd.read_csv('data/corrected_data.csv')
# df_read = pd.read_csv('data/meter_corrected.csv')
# df_read = pd.read_csv('data/chol-bangkla-corrected-2017-2022-hourly-corrected.csv', parse_dates=["datetime"])
df_read = pd.read_csv('data/chol-bangkla-corrected-2017-2022-hourly.csv', parse_dates=["datetime"])

# %%
df = df_read.copy()
print(df.dtypes)
# Out:
# datetime    datetime64[ns]
# ec                 float64
# dtype: object

# %%
df = df.loc[df["datetime"].dt.year==2022]
df.sort_values(by=['datetime'],inplace=True)
df.reset_index(drop=True,inplace=True)

# %%
plt.figure(figsize=(16,32))
plt.subplot(3,1,1)
plt.title('Displays EC values.')
plt.xlabel('Date')
plt.ylabel('EC')
# plt.plot(df_read_original['ec'], label='Original')
# plt.plot(df['ec'], label='Corrected')
plt.plot(df['ec'], label='Original')
plt.legend()

# plt.subplot(3,1,2)
# plt.title('Displays Temp. values from March to September.')
# plt.xlabel('Date')
# plt.ylabel('°C')
# plt.plot(df['temperature'], label='OG temp.')
# plt.plot(df['temp_new_1'], label='temp_new_1')
# plt.plot(df['temp_new_2'], label='temp_new_2')
# plt.plot(df['temp_new_3'], label='temp_new_3')
# plt.plot(df['temp_new_4'], label='temp_new_4')
# plt.plot(df['temp_new_.5'], label='temp_new_.5')
# plt.legend()

# plt.subplot(3,1,3)
# plt.title('Displays pH. values from March to September.')
# plt.xlabel('Date')
# plt.ylabel('pH')
# plt.plot(df['pH'], label='OG pH')
# plt.plot(df['pH_new_1'], label='pH_new_1')
# plt.plot(df['pH_new_2'], label='pH_new_2')
# plt.plot(df['pH_new_3'], label='pH_new_3')
# plt.plot(df['pH_new_4'], label='pH_new_4')
# plt.plot(df['pH_new_.5'], label='pH_new_.5')
# plt.legend()

# %%
# =============================================================================
# กำหนดตัวแปรที่ต้องการใช้ train ตัว model
# =============================================================================

data = df.filter(['ec'])
dataset = data.values

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
# =============================================================================
# MinMaxScaler
# =============================================================================

scaler = MinMaxScaler(feature_range=(0,1))
scaler = scaler.fit(dataset)
dataset_scaled = scaler.transform(dataset)

# dataset_scaled = scaler.fit_transform(dataset)

# %%
n_future = 24
n_past = 48

# %%
import math

train_set_len = math.ceil(len(dataset) * 0.80)
valid_set_len = math.ceil(len(dataset) * 0.10)

# # first 3yrs
# train_set_len = 26280

# # last year
# valid_set_len = 17544

# %%
train_set = dataset_scaled[0:train_set_len, :]

x_train = []
y_train = []

for i in range(n_past, len(train_set) - n_future + 1):
    x_train.append(train_set[i - n_past:i, 0:dataset.shape[1]])
    y_train.append(train_set[i:i + n_future, 0])

# %%
x_train, y_train = np.array(x_train), np.array(y_train)
y_train = np.reshape(y_train, (y_train.shape[0], y_train.shape[1], 1))

# %%
valid_set = dataset_scaled[train_set_len - n_past:train_set_len + valid_set_len, :]

x_valid = []
y_valid = []

for i in range(n_past, len(valid_set) - n_future + 1):
    x_valid.append(valid_set[i - n_past:i, 0:dataset.shape[1]])
    y_valid.append(valid_set[i:i + n_future, 0])

# %%
x_valid, y_valid = np.array(x_valid), np.array(y_valid)
y_valid = np.reshape(y_valid, (y_valid.shape[0], y_valid.shape[1], 1))

# %%
test_set = dataset_scaled[(train_set_len + valid_set_len) - n_past:, :]
test_real = dataset[(train_set_len + valid_set_len) - n_past:, :]

x_test = []
y_test = []

for i in range(n_past, len(test_set) - n_future + 1):
    x_test.append(test_set[i - n_past:i, 0:dataset.shape[1]])
    y_test.append(test_real[i:i + n_future, 0])

# %%
x_test, y_test = np.array(x_test), np.array(y_test)
y_test = np.reshape(y_test, (y_test.shape[0], y_test.shape[1], 1))

# %%
plt.figure(figsize=(16,8))
plt.title('Displays Train set, Validation set, and Test set.')
plt.xlabel('Date')
plt.ylabel('EC')
plt.plot(df[0:train_set_len]["ec"], label='Train')
plt.plot(df[train_set_len - n_past:train_set_len + valid_set_len]["ec"], label='Validation')
plt.plot(df[(train_set_len + valid_set_len) - n_past:]["ec"], label='Test')
plt.legend()
plt.show()

# %%
from keras import Model
from keras.models import Sequential
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import SimpleRNN
from keras.layers import LSTM
# from keras.layers import CuDNNLSTM
from keras.layers import Bidirectional
# from tensorflow.keras.layers import Bidirectional
from keras.optimizers import Adam, SGD, RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# =============================================================================
# LSTM
# =============================================================================

model = Sequential()
model.add(LSTM(192, return_sequences=True, input_shape=(x_train.shape[1],x_train.shape[2])))
# model.add(LSTM(192, return_sequences=True))
model.add(LSTM(192, return_sequences=False))
model.add(Dense(n_future))

# model = Sequential()
# model.add(LSTM(128, return_sequences=True, input_shape=(x_train.shape[1],x_train.shape[2])))
# model.add(LSTM(64, return_sequences=False))
# model.add(Dense(n_future))
# model.add(Dense(16))
# model.add(Dense(1))

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 48, 192)           148992
#
#  lstm_1 (LSTM)               (None, 192)               295680
#
#  dense (Dense)               (None, 24)                4632
#
# =================================================================
# Total params: 449,304
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 48, 192)           148992
#
#  lstm_1 (LSTM)               (None, 192)               295680
#
#  dense (Dense)               (None, 24)                4632
#
# =================================================================
# Total params: 449,304
# Trainable params: 449,304
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=20)

# %%
# checkpoint_filepath = 'checkpoint/lstm-meter-24-3-2-1-gpu-batch-24.h5'
checkpoint_filepath = 'checkpoint/lstm-24-2022-batch-24.h5'
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_freq='epoch',
    verbose=1
    )

# %%
model_fit = model.fit(
    x_train,
    y_train,
    batch_size=24,
    epochs=128,
    validation_data=(x_valid, y_valid),
    callbacks=[model_checkpoint_callback, early_stopping_callback]
    )
# Out:
# Epoch 1/128
# 289/290 [============================>.] - ETA: 0s - loss: 0.0032 - mse: 0.0032
# Epoch 1: val_loss improved from inf to 0.00001, saving model to checkpoint\lstm-24-2022-batch-24.h5
# 290/290 [==============================] - 37s 111ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 9.0319e-06 - val_mse: 9.0319e-06
# Epoch 2/128
# 289/290 [============================>.] - ETA: 0s - loss: 9.9563e-04 - mse: 9.9563e-04
# Epoch 2: val_loss did not improve from 0.00001
# 290/290 [==============================] - 31s 108ms/step - loss: 9.9582e-04 - mse: 9.9582e-04 - val_loss: 2.8909e-05 - val_mse: 2.8909e-05
# Epoch 3/128
# 289/290 [============================>.] - ETA: 0s - loss: 9.9142e-04 - mse: 9.9142e-04
# Epoch 3: val_loss did not improve from 0.00001
# 290/290 [==============================] - 33s 113ms/step - loss: 9.9128e-04 - mse: 9.9128e-04 - val_loss: 3.9434e-05 - val_mse: 3.9434e-05
# Epoch 4/128
# 289/290 [============================>.] - ETA: 0s - loss: 8.1819e-04 - mse: 8.1819e-04
# Epoch 4: val_loss did not improve from 0.00001
# 290/290 [==============================] - 34s 117ms/step - loss: 8.1807e-04 - mse: 8.1807e-04 - val_loss: 1.1843e-05 - val_mse: 1.1843e-05
# Epoch 5/128
# 289/290 [============================>.] - ETA: 0s - loss: 6.2245e-04 - mse: 6.2245e-04
# Epoch 5: val_loss did not improve from 0.00001
# 290/290 [==============================] - 32s 112ms/step - loss: 6.2236e-04 - mse: 6.2236e-04 - val_loss: 3.7497e-05 - val_mse: 3.7497e-05
# Epoch 6/128
# 289/290 [============================>.] - ETA: 0s - loss: 6.0911e-04 - mse: 6.0911e-04
# Epoch 6: val_loss did not improve from 0.00001
# 290/290 [==============================] - 34s 117ms/step - loss: 6.0902e-04 - mse: 6.0902e-04 - val_loss: 9.5995e-06 - val_mse: 9.5995e-06
# Epoch 7/128
# 289/290 [============================>.] - ETA: 0s - loss: 5.1186e-04 - mse: 5.1186e-04
# Epoch 7: val_loss improved from 0.00001 to 0.00001, saving model to checkpoint\lstm-24-2022-batch-24.h5
# 290/290 [==============================] - 34s 116ms/step - loss: 5.1179e-04 - mse: 5.1179e-04 - val_loss: 5.6303e-06 - val_mse: 5.6303e-06
# Epoch 8/128
# 290/290 [==============================] - ETA: 0s - loss: 5.4673e-04 - mse: 5.4673e-04
# Epoch 8: val_loss did not improve from 0.00001
# 290/290 [==============================] - 33s 114ms/step - loss: 5.4673e-04 - mse: 5.4673e-04 - val_loss: 1.3908e-05 - val_mse: 1.3908e-05
# Epoch 9/128
# 290/290 [==============================] - ETA: 0s - loss: 5.1379e-04 - mse: 5.1379e-04
# Epoch 9: val_loss did not improve from 0.00001
# 290/290 [==============================] - 32s 110ms/step - loss: 5.1379e-04 - mse: 5.1379e-04 - val_loss: 8.5168e-06 - val_mse: 8.5168e-06
# Epoch 10/128
# 289/290 [============================>.] - ETA: 0s - loss: 5.2616e-04 - mse: 5.2616e-04
# Epoch 10: val_loss did not improve from 0.00001
# 290/290 [==============================] - 34s 116ms/step - loss: 5.2609e-04 - mse: 5.2609e-04 - val_loss: 8.7941e-06 - val_mse: 8.7941e-06
# Epoch 11/128
# 289/290 [============================>.] - ETA: 0s - loss: 4.5890e-04 - mse: 4.5890e-04
# Epoch 11: val_loss did not improve from 0.00001
# 290/290 [==============================] - 35s 122ms/step - loss: 4.5962e-04 - mse: 4.5962e-04 - val_loss: 3.8051e-05 - val_mse: 3.8051e-05
# Epoch 12/128
# 290/290 [==============================] - ETA: 0s - loss: 7.4376e-04 - mse: 7.4376e-04
# Epoch 12: val_loss did not improve from 0.00001
# 290/290 [==============================] - 37s 128ms/step - loss: 7.4376e-04 - mse: 7.4376e-04 - val_loss: 1.1209e-05 - val_mse: 1.1209e-05
# Epoch 13/128
# 289/290 [============================>.] - ETA: 0s - loss: 4.4999e-04 - mse: 4.4999e-04
# Epoch 13: val_loss did not improve from 0.00001
# 290/290 [==============================] - 36s 126ms/step - loss: 4.5016e-04 - mse: 4.5016e-04 - val_loss: 3.2392e-05 - val_mse: 3.2392e-05
# Epoch 14/128
# 289/290 [============================>.] - ETA: 0s - loss: 4.5632e-04 - mse: 4.5632e-04
# Epoch 14: val_loss improved from 0.00001 to 0.00001, saving model to checkpoint\lstm-24-2022-batch-24.h5
# 290/290 [==============================] - 35s 119ms/step - loss: 4.5626e-04 - mse: 4.5626e-04 - val_loss: 5.0941e-06 - val_mse: 5.0941e-06
# Epoch 15/128
# 289/290 [============================>.] - ETA: 0s - loss: 3.9514e-04 - mse: 3.9514e-04
# Epoch 15: val_loss did not improve from 0.00001
# 290/290 [==============================] - 36s 124ms/step - loss: 3.9511e-04 - mse: 3.9511e-04 - val_loss: 3.9947e-05 - val_mse: 3.9947e-05
# Epoch 16/128
# 290/290 [==============================] - ETA: 0s - loss: 4.3003e-04 - mse: 4.3003e-04
# Epoch 16: val_loss did not improve from 0.00001
# 290/290 [==============================] - 35s 122ms/step - loss: 4.3003e-04 - mse: 4.3003e-04 - val_loss: 9.0925e-06 - val_mse: 9.0925e-06
# Epoch 17/128
# 289/290 [============================>.] - ETA: 0s - loss: 4.1323e-04 - mse: 4.1323e-04
# Epoch 17: val_loss did not improve from 0.00001
# 290/290 [==============================] - 34s 118ms/step - loss: 4.1326e-04 - mse: 4.1326e-04 - val_loss: 9.0209e-05 - val_mse: 9.0209e-05
# Epoch 18/128
# 290/290 [==============================] - ETA: 0s - loss: 4.1426e-04 - mse: 4.1426e-04
# Epoch 18: val_loss did not improve from 0.00001
# 290/290 [==============================] - 36s 125ms/step - loss: 4.1426e-04 - mse: 4.1426e-04 - val_loss: 1.8556e-05 - val_mse: 1.8556e-05
# Epoch 19/128
# 290/290 [==============================] - ETA: 0s - loss: 4.0823e-04 - mse: 4.0823e-04
# Epoch 19: val_loss improved from 0.00001 to 0.00000, saving model to checkpoint\lstm-24-2022-batch-24.h5
# 290/290 [==============================] - 38s 129ms/step - loss: 4.0823e-04 - mse: 4.0823e-04 - val_loss: 4.4169e-06 - val_mse: 4.4169e-06
# Epoch 20/128
# 289/290 [============================>.] - ETA: 0s - loss: 4.3904e-04 - mse: 4.3904e-04
# Epoch 20: val_loss did not improve from 0.00000
# 290/290 [==============================] - 37s 129ms/step - loss: 4.3898e-04 - mse: 4.3898e-04 - val_loss: 1.3705e-05 - val_mse: 1.3705e-05
# Epoch 21/128
# 289/290 [============================>.] - ETA: 0s - loss: 3.8489e-04 - mse: 3.8489e-04
# Epoch 21: val_loss did not improve from 0.00000
# 290/290 [==============================] - 33s 115ms/step - loss: 3.8484e-04 - mse: 3.8484e-04 - val_loss: 4.4394e-06 - val_mse: 4.4394e-06
# Epoch 22/128
# 289/290 [============================>.] - ETA: 0s - loss: 3.8414e-04 - mse: 3.8414e-04
# Epoch 22: val_loss did not improve from 0.00000
# 290/290 [==============================] - 37s 126ms/step - loss: 3.8409e-04 - mse: 3.8409e-04 - val_loss: 9.0528e-06 - val_mse: 9.0528e-06
# Epoch 23/128
# 290/290 [==============================] - ETA: 0s - loss: 3.8867e-04 - mse: 3.8867e-04
# Epoch 23: val_loss did not improve from 0.00000
# 290/290 [==============================] - 34s 118ms/step - loss: 3.8867e-04 - mse: 3.8867e-04 - val_loss: 8.1187e-06 - val_mse: 8.1187e-06
# Epoch 24/128
# 289/290 [============================>.] - ETA: 0s - loss: 3.5635e-04 - mse: 3.5635e-04
# Epoch 24: val_loss did not improve from 0.00000
# 290/290 [==============================] - 35s 119ms/step - loss: 3.5654e-04 - mse: 3.5654e-04 - val_loss: 2.2157e-04 - val_mse: 2.2157e-04
# Epoch 25/128
# 289/290 [============================>.] - ETA: 0s - loss: 3.8478e-04 - mse: 3.8478e-04
# Epoch 25: val_loss improved from 0.00000 to 0.00000, saving model to checkpoint\lstm-24-2022-batch-24.h5
# 290/290 [==============================] - 35s 120ms/step - loss: 3.8473e-04 - mse: 3.8473e-04 - val_loss: 3.3571e-06 - val_mse: 3.3571e-06
# Epoch 26/128
# 289/290 [============================>.] - ETA: 0s - loss: 3.6670e-04 - mse: 3.6670e-04
# Epoch 26: val_loss did not improve from 0.00000
# 290/290 [==============================] - 35s 120ms/step - loss: 3.6665e-04 - mse: 3.6665e-04 - val_loss: 8.8262e-06 - val_mse: 8.8262e-06
# Epoch 27/128
# 289/290 [============================>.] - ETA: 0s - loss: 3.8147e-04 - mse: 3.8147e-04
# Epoch 27: val_loss did not improve from 0.00000
# 290/290 [==============================] - 34s 116ms/step - loss: 3.8142e-04 - mse: 3.8142e-04 - val_loss: 4.1609e-06 - val_mse: 4.1609e-06
# Epoch 28/128
# 290/290 [==============================] - ETA: 0s - loss: 3.4506e-04 - mse: 3.4506e-04
# Epoch 28: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 111ms/step - loss: 3.4506e-04 - mse: 3.4506e-04 - val_loss: 5.7537e-05 - val_mse: 5.7537e-05
# Epoch 29/128
# 290/290 [==============================] - ETA: 0s - loss: 4.3781e-04 - mse: 4.3781e-04
# Epoch 29: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 112ms/step - loss: 4.3781e-04 - mse: 4.3781e-04 - val_loss: 2.2201e-05 - val_mse: 2.2201e-05
# Epoch 30/128
# 289/290 [============================>.] - ETA: 0s - loss: 3.7265e-04 - mse: 3.7265e-04
# Epoch 30: val_loss did not improve from 0.00000
# 290/290 [==============================] - 33s 112ms/step - loss: 3.7260e-04 - mse: 3.7260e-04 - val_loss: 1.2348e-05 - val_mse: 1.2348e-05
# Epoch 31/128
# 289/290 [============================>.] - ETA: 0s - loss: 3.0968e-04 - mse: 3.0968e-04
# Epoch 31: val_loss did not improve from 0.00000
# 290/290 [==============================] - 33s 115ms/step - loss: 3.0963e-04 - mse: 3.0963e-04 - val_loss: 9.3069e-06 - val_mse: 9.3069e-06
# Epoch 32/128
# 289/290 [============================>.] - ETA: 0s - loss: 3.2250e-04 - mse: 3.2250e-04
# Epoch 32: val_loss did not improve from 0.00000
# 290/290 [==============================] - 33s 115ms/step - loss: 3.2245e-04 - mse: 3.2245e-04 - val_loss: 3.9476e-06 - val_mse: 3.9476e-06
# Epoch 33/128
# 289/290 [============================>.] - ETA: 0s - loss: 2.9870e-04 - mse: 2.9870e-04
# Epoch 33: val_loss did not improve from 0.00000
# 290/290 [==============================] - 34s 116ms/step - loss: 2.9866e-04 - mse: 2.9866e-04 - val_loss: 1.1176e-05 - val_mse: 1.1176e-05
# Epoch 34/128
# 290/290 [==============================] - ETA: 0s - loss: 3.0697e-04 - mse: 3.0697e-04
# Epoch 34: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 111ms/step - loss: 3.0697e-04 - mse: 3.0697e-04 - val_loss: 9.0689e-06 - val_mse: 9.0689e-06
# Epoch 35/128
# 289/290 [============================>.] - ETA: 0s - loss: 2.9375e-04 - mse: 2.9375e-04
# Epoch 35: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 110ms/step - loss: 2.9371e-04 - mse: 2.9371e-04 - val_loss: 4.5381e-06 - val_mse: 4.5381e-06
# Epoch 36/128
# 289/290 [============================>.] - ETA: 0s - loss: 3.0180e-04 - mse: 3.0180e-04
# Epoch 36: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 111ms/step - loss: 3.0176e-04 - mse: 3.0176e-04 - val_loss: 3.1101e-05 - val_mse: 3.1101e-05
# Epoch 37/128
# 289/290 [============================>.] - ETA: 0s - loss: 2.7146e-04 - mse: 2.7146e-04
# Epoch 37: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 110ms/step - loss: 2.7144e-04 - mse: 2.7144e-04 - val_loss: 3.4733e-05 - val_mse: 3.4733e-05
# Epoch 38/128
# 289/290 [============================>.] - ETA: 0s - loss: 2.6962e-04 - mse: 2.6962e-04
# Epoch 38: val_loss did not improve from 0.00000
# 290/290 [==============================] - 33s 112ms/step - loss: 2.6969e-04 - mse: 2.6969e-04 - val_loss: 9.8075e-06 - val_mse: 9.8075e-06
# Epoch 39/128
# 289/290 [============================>.] - ETA: 0s - loss: 2.9687e-04 - mse: 2.9687e-04
# Epoch 39: val_loss did not improve from 0.00000
# 290/290 [==============================] - 33s 113ms/step - loss: 2.9700e-04 - mse: 2.9700e-04 - val_loss: 5.4588e-05 - val_mse: 5.4588e-05
# Epoch 40/128
# 289/290 [============================>.] - ETA: 0s - loss: 2.7219e-04 - mse: 2.7219e-04
# Epoch 40: val_loss improved from 0.00000 to 0.00000, saving model to checkpoint\lstm-24-2022-batch-24.h5
# 290/290 [==============================] - 33s 113ms/step - loss: 2.7216e-04 - mse: 2.7216e-04 - val_loss: 3.3247e-06 - val_mse: 3.3247e-06
# Epoch 41/128
# 289/290 [============================>.] - ETA: 0s - loss: 2.4212e-04 - mse: 2.4212e-04
# Epoch 41: val_loss did not improve from 0.00000
# 290/290 [==============================] - 33s 112ms/step - loss: 2.4209e-04 - mse: 2.4209e-04 - val_loss: 4.6124e-06 - val_mse: 4.6124e-06
# Epoch 42/128
# 289/290 [============================>.] - ETA: 0s - loss: 2.4004e-04 - mse: 2.4004e-04
# Epoch 42: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 111ms/step - loss: 2.4001e-04 - mse: 2.4001e-04 - val_loss: 4.2540e-06 - val_mse: 4.2540e-06
# Epoch 43/128
# 290/290 [==============================] - ETA: 0s - loss: 2.3216e-04 - mse: 2.3216e-04
# Epoch 43: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 112ms/step - loss: 2.3216e-04 - mse: 2.3216e-04 - val_loss: 5.3306e-06 - val_mse: 5.3306e-06
# Epoch 44/128
# 289/290 [============================>.] - ETA: 0s - loss: 2.2442e-04 - mse: 2.2442e-04
# Epoch 44: val_loss did not improve from 0.00000
# 290/290 [==============================] - 33s 113ms/step - loss: 2.2439e-04 - mse: 2.2439e-04 - val_loss: 8.3860e-06 - val_mse: 8.3860e-06
# Epoch 45/128
# 289/290 [============================>.] - ETA: 0s - loss: 2.2102e-04 - mse: 2.2102e-04
# Epoch 45: val_loss improved from 0.00000 to 0.00000, saving model to checkpoint\lstm-24-2022-batch-24.h5
# 290/290 [==============================] - 33s 112ms/step - loss: 2.2099e-04 - mse: 2.2099e-04 - val_loss: 3.1600e-06 - val_mse: 3.1600e-06
# Epoch 46/128
# 289/290 [============================>.] - ETA: 0s - loss: 2.0087e-04 - mse: 2.0087e-04
# Epoch 46: val_loss did not improve from 0.00000
# 290/290 [==============================] - 33s 113ms/step - loss: 2.0093e-04 - mse: 2.0093e-04 - val_loss: 5.9481e-05 - val_mse: 5.9481e-05
# Epoch 47/128
# 290/290 [==============================] - ETA: 0s - loss: 2.3318e-04 - mse: 2.3318e-04
# Epoch 47: val_loss did not improve from 0.00000
# 290/290 [==============================] - 33s 112ms/step - loss: 2.3318e-04 - mse: 2.3318e-04 - val_loss: 1.1085e-05 - val_mse: 1.1085e-05
# Epoch 48/128
# 289/290 [============================>.] - ETA: 0s - loss: 2.0585e-04 - mse: 2.0585e-04
# Epoch 48: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 112ms/step - loss: 2.0582e-04 - mse: 2.0582e-04 - val_loss: 4.0436e-06 - val_mse: 4.0436e-06
# Epoch 49/128
# 289/290 [============================>.] - ETA: 0s - loss: 1.8692e-04 - mse: 1.8692e-04
# Epoch 49: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 112ms/step - loss: 1.8706e-04 - mse: 1.8706e-04 - val_loss: 4.3655e-06 - val_mse: 4.3655e-06
# Epoch 50/128
# 289/290 [============================>.] - ETA: 0s - loss: 2.2223e-04 - mse: 2.2223e-04
# Epoch 50: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 112ms/step - loss: 2.2223e-04 - mse: 2.2223e-04 - val_loss: 2.8858e-05 - val_mse: 2.8858e-05
# Epoch 51/128
# 289/290 [============================>.] - ETA: 0s - loss: 1.8096e-04 - mse: 1.8096e-04
# Epoch 51: val_loss did not improve from 0.00000
# 290/290 [==============================] - 33s 113ms/step - loss: 1.8102e-04 - mse: 1.8102e-04 - val_loss: 3.5893e-06 - val_mse: 3.5893e-06
# Epoch 52/128
# 289/290 [============================>.] - ETA: 0s - loss: 2.0549e-04 - mse: 2.0549e-04
# Epoch 52: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 111ms/step - loss: 2.0559e-04 - mse: 2.0559e-04 - val_loss: 2.7221e-05 - val_mse: 2.7221e-05
# Epoch 53/128
# 289/290 [============================>.] - ETA: 0s - loss: 2.3554e-04 - mse: 2.3554e-04
# Epoch 53: val_loss improved from 0.00000 to 0.00000, saving model to checkpoint\lstm-24-2022-batch-24.h5
# 290/290 [==============================] - 32s 109ms/step - loss: 2.3551e-04 - mse: 2.3551e-04 - val_loss: 2.8424e-06 - val_mse: 2.8424e-06
# Epoch 54/128
# 289/290 [============================>.] - ETA: 0s - loss: 1.7655e-04 - mse: 1.7655e-04
# Epoch 54: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 109ms/step - loss: 1.7658e-04 - mse: 1.7658e-04 - val_loss: 7.2286e-06 - val_mse: 7.2286e-06
# Epoch 55/128
# 289/290 [============================>.] - ETA: 0s - loss: 1.9577e-04 - mse: 1.9577e-04
# Epoch 55: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 110ms/step - loss: 1.9608e-04 - mse: 1.9608e-04 - val_loss: 8.3785e-05 - val_mse: 8.3785e-05
# Epoch 56/128
# 289/290 [============================>.] - ETA: 0s - loss: 2.2315e-04 - mse: 2.2315e-04
# Epoch 56: val_loss improved from 0.00000 to 0.00000, saving model to checkpoint\lstm-24-2022-batch-24.h5
# 290/290 [==============================] - 32s 112ms/step - loss: 2.2312e-04 - mse: 2.2312e-04 - val_loss: 2.2866e-06 - val_mse: 2.2866e-06
# Epoch 57/128
# 289/290 [============================>.] - ETA: 0s - loss: 1.6471e-04 - mse: 1.6471e-04
# Epoch 57: val_loss did not improve from 0.00000
# 290/290 [==============================] - 33s 114ms/step - loss: 1.6485e-04 - mse: 1.6485e-04 - val_loss: 6.0671e-06 - val_mse: 6.0671e-06
# Epoch 58/128
# 289/290 [============================>.] - ETA: 0s - loss: 2.5269e-04 - mse: 2.5269e-04
# Epoch 58: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 111ms/step - loss: 2.5265e-04 - mse: 2.5265e-04 - val_loss: 4.2751e-06 - val_mse: 4.2751e-06
# Epoch 59/128
# 289/290 [============================>.] - ETA: 0s - loss: 1.5544e-04 - mse: 1.5544e-04
# Epoch 59: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 110ms/step - loss: 1.5543e-04 - mse: 1.5543e-04 - val_loss: 9.8527e-06 - val_mse: 9.8527e-06
# Epoch 60/128
# 289/290 [============================>.] - ETA: 0s - loss: 1.6116e-04 - mse: 1.6116e-04
# Epoch 60: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 111ms/step - loss: 1.6114e-04 - mse: 1.6114e-04 - val_loss: 5.2310e-06 - val_mse: 5.2310e-06
# Epoch 61/128
# 289/290 [============================>.] - ETA: 0s - loss: 1.5654e-04 - mse: 1.5654e-04
# Epoch 61: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 112ms/step - loss: 1.5652e-04 - mse: 1.5652e-04 - val_loss: 4.7032e-06 - val_mse: 4.7032e-06
# Epoch 62/128
# 289/290 [============================>.] - ETA: 0s - loss: 1.5065e-04 - mse: 1.5065e-04
# Epoch 62: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 111ms/step - loss: 1.5063e-04 - mse: 1.5063e-04 - val_loss: 2.7245e-06 - val_mse: 2.7245e-06
# Epoch 63/128
# 289/290 [============================>.] - ETA: 0s - loss: 1.4345e-04 - mse: 1.4345e-04
# Epoch 63: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 111ms/step - loss: 1.4344e-04 - mse: 1.4344e-04 - val_loss: 3.4918e-06 - val_mse: 3.4918e-06
# Epoch 64/128
# 289/290 [============================>.] - ETA: 0s - loss: 1.4319e-04 - mse: 1.4319e-04
# Epoch 64: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 112ms/step - loss: 1.4317e-04 - mse: 1.4317e-04 - val_loss: 3.4952e-06 - val_mse: 3.4952e-06
# Epoch 65/128
# 289/290 [============================>.] - ETA: 0s - loss: 1.5022e-04 - mse: 1.5022e-04
# Epoch 65: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 110ms/step - loss: 1.5020e-04 - mse: 1.5020e-04 - val_loss: 3.1351e-06 - val_mse: 3.1351e-06
# Epoch 66/128
# 290/290 [==============================] - ETA: 0s - loss: 1.3332e-04 - mse: 1.3332e-04
# Epoch 66: val_loss did not improve from 0.00000
# 290/290 [==============================] - 33s 115ms/step - loss: 1.3332e-04 - mse: 1.3332e-04 - val_loss: 4.8731e-06 - val_mse: 4.8731e-06
# Epoch 67/128
# 289/290 [============================>.] - ETA: 0s - loss: 1.4222e-04 - mse: 1.4222e-04
# Epoch 67: val_loss did not improve from 0.00000
# 290/290 [==============================] - 35s 120ms/step - loss: 1.4223e-04 - mse: 1.4223e-04 - val_loss: 2.9812e-06 - val_mse: 2.9812e-06
# Epoch 68/128
# 289/290 [============================>.] - ETA: 0s - loss: 1.4230e-04 - mse: 1.4230e-04
# Epoch 68: val_loss did not improve from 0.00000
# 290/290 [==============================] - 34s 118ms/step - loss: 1.4229e-04 - mse: 1.4229e-04 - val_loss: 1.0040e-05 - val_mse: 1.0040e-05
# Epoch 69/128
# 289/290 [============================>.] - ETA: 0s - loss: 1.3512e-04 - mse: 1.3512e-04
# Epoch 69: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 111ms/step - loss: 1.3511e-04 - mse: 1.3511e-04 - val_loss: 5.8254e-06 - val_mse: 5.8254e-06
# Epoch 70/128
# 289/290 [============================>.] - ETA: 0s - loss: 1.2620e-04 - mse: 1.2620e-04
# Epoch 70: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 112ms/step - loss: 1.2619e-04 - mse: 1.2619e-04 - val_loss: 4.9299e-06 - val_mse: 4.9299e-06
# Epoch 71/128
# 289/290 [============================>.] - ETA: 0s - loss: 1.2102e-04 - mse: 1.2102e-04
# Epoch 71: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 111ms/step - loss: 1.2100e-04 - mse: 1.2100e-04 - val_loss: 8.0794e-06 - val_mse: 8.0794e-06
# Epoch 72/128
# 289/290 [============================>.] - ETA: 0s - loss: 1.3468e-04 - mse: 1.3468e-04
# Epoch 72: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 111ms/step - loss: 1.3466e-04 - mse: 1.3466e-04 - val_loss: 5.5063e-06 - val_mse: 5.5063e-06
# Epoch 73/128
# 289/290 [============================>.] - ETA: 0s - loss: 1.0871e-04 - mse: 1.0871e-04
# Epoch 73: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 110ms/step - loss: 1.0871e-04 - mse: 1.0871e-04 - val_loss: 8.3554e-06 - val_mse: 8.3554e-06
# Epoch 74/128
# 289/290 [============================>.] - ETA: 0s - loss: 1.1658e-04 - mse: 1.1658e-04
# Epoch 74: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 109ms/step - loss: 1.1656e-04 - mse: 1.1656e-04 - val_loss: 4.2052e-06 - val_mse: 4.2052e-06
# Epoch 75/128
# 289/290 [============================>.] - ETA: 0s - loss: 1.0823e-04 - mse: 1.0823e-04
# Epoch 75: val_loss did not improve from 0.00000
# 290/290 [==============================] - 32s 110ms/step - loss: 1.0827e-04 - mse: 1.0827e-04 - val_loss: 1.5442e-05 - val_mse: 1.5442e-05
# Epoch 76/128
# 290/290 [==============================] - ETA: 0s - loss: 1.1934e-04 - mse: 1.1934e-04
# Epoch 76: val_loss did not improve from 0.00000
# 290/290 [==============================] - 33s 114ms/step - loss: 1.1934e-04 - mse: 1.1934e-04 - val_loss: 5.3294e-06 - val_mse: 5.3294e-06

# %%
plt.figure(figsize=(16,8))
plt.title('LSTM: loss rate')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(model_fit.history['loss'], label='Training loss')
plt.plot(model_fit.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()


# #%%
# from keras.models import load_model

# model = load_model('checkpoint/01-bilstm-24-3-2-1.h5')

# #%%
# pred = model.predict(x_test)

# #%%
# if dataset.shape[1] > 1:
#     pred = np.repeat(pred, dataset.shape[1], axis=-1)

# #%%
# y_pred = scaler.inverse_transform(pred)[:,0]

# #%%
# y_pred = np.reshape(y_pred, (y_pred.shape[0], 1))

# #%%
# from sklearn.metrics import mean_squared_error

# rmse = mean_squared_error(y_test, y_pred, squared=False)
# print(f'RMSE of Bi-LSTM = {rmse}')            

# #%%
# # rmse = np.sqrt(np.mean(np.square((y_test - y_pred))))
# # print(rmse)

# #%%
# rmspe = (np.sqrt(np.mean(np.square((y_test - y_pred) / y_test)))) * 100
# print(f'RMSPE of Bi-LSTM = {rmspe}')


# #%%
# df_compare = pd.DataFrame({'Actual EC':df['ec_corrected'][train_set_len + valid_set_len:]})
# df_compare['Predicted EC'] = y_pred

# #%%
# plt.figure(figsize=(16,8))
# plt.title('Displays Actual EC vs. Predicted EC.')
# plt.xlabel('Date')
# plt.ylabel('Value')
# plt.plot(df_compare['Actual EC'], label='Actual')
# plt.plot(df_compare['Predicted EC'], label='Predicted')
# plt.legend()
# plt.show()

# #%%
# plt.figure(figsize=(16,8))
# plt.title('Displays All Actual EC vs. Predicted EC.')
# plt.xlabel('Date')
# plt.ylabel('Value')
# plt.plot(df['ec_new_.5'], label='All Actual EC')
# plt.plot(df_compare['Predicted EC'], label='Predicted')
# plt.legend()
# plt.show()

# %%
from keras.models import load_model

model = load_model('checkpoint/lstm-24-2022-batch-24.h5')

# %%
pred = model.predict(x_test)
# Out:
# 27/27 [==============================] - 2s 34ms/step

# %%
rpred = None

# %%
for i in range(pred.shape[1]):
    tpred = pred[:,i]
    tpred = np.reshape(tpred, (tpred.shape[0], 1))
    tpred = np.repeat(tpred, dataset.shape[1], axis=-1)
    tpred = scaler.inverse_transform(tpred)[:,0]
    tpred = np.reshape(tpred, (tpred.shape[0], 1))
    if rpred is None:
        rpred = tpred
    else:
        rpred = np.append(rpred, tpred, axis=1)

# %%
y_pred = rpred[:,0]
y_pred = np.reshape(y_pred, (y_pred.shape[0], 1))

# %%
y_test = np.reshape(y_test, (y_test.shape[0], y_test.shape[1]))

# %%
y_real = y_test[:,0]
y_real = np.reshape(y_real, (y_real.shape[0], 1))

# %%
plt.figure(figsize=(16,8))
plt.title('LSTM')
plt.plot(y_real, label='y_real')
plt.plot(y_pred, label='y_pred')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error

rmse = mean_squared_error(y_test, rpred, squared=False)
print("RMSE of LSTM =",rmse)
# Out:
# RMSE of LSTM = 30.487332435923076

# %%
from sklearn.metrics import mean_absolute_percentage_error

# calculate MAPE
mape = mean_absolute_percentage_error(y_test, rpred)
print(f'MAPE of LSTM = {mape}')
# Out:
# MAPE of LSTM = 0.07285345447945384
