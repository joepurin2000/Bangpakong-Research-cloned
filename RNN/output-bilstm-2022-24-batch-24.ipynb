# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'Angsana New'
rcParams.update({'font.size': 22})
rcParams['axes.unicode_minus'] = False

# %%
# df_read = pd.read_csv('data/corrected_data.csv')
# df_read = pd.read_csv('data/meter_corrected.csv')
# df_read = pd.read_csv('data/chol-bangkla-corrected-2017-2022-hourly-corrected.csv', parse_dates=["datetime"])
df_read = pd.read_csv('data/chol-bangkla-corrected-2017-2022-hourly.csv', parse_dates=["datetime"])

# %%
df = df_read.copy()
print(df.dtypes)
# Out:
# datetime    datetime64[ns]
# ec                 float64
# dtype: object

# %%
df = df.loc[df["datetime"].dt.year==2022]
df.sort_values(by=['datetime'],inplace=True)
df.reset_index(drop=True,inplace=True)

# %%
plt.figure(figsize=(16,32))
plt.subplot(3,1,1)
plt.title('Displays EC values.')
plt.xlabel('Date')
plt.ylabel('EC')
# plt.plot(df_read_original['ec'], label='Original')
# plt.plot(df['ec'], label='Corrected')
plt.plot(df['ec'], label='Original')
plt.legend()

# plt.subplot(3,1,2)
# plt.title('Displays Temp. values from March to September.')
# plt.xlabel('Date')
# plt.ylabel('°C')
# plt.plot(df['temperature'], label='OG temp.')
# plt.plot(df['temp_new_1'], label='temp_new_1')
# plt.plot(df['temp_new_2'], label='temp_new_2')
# plt.plot(df['temp_new_3'], label='temp_new_3')
# plt.plot(df['temp_new_4'], label='temp_new_4')
# plt.plot(df['temp_new_.5'], label='temp_new_.5')
# plt.legend()

# plt.subplot(3,1,3)
# plt.title('Displays pH. values from March to September.')
# plt.xlabel('Date')
# plt.ylabel('pH')
# plt.plot(df['pH'], label='OG pH')
# plt.plot(df['pH_new_1'], label='pH_new_1')
# plt.plot(df['pH_new_2'], label='pH_new_2')
# plt.plot(df['pH_new_3'], label='pH_new_3')
# plt.plot(df['pH_new_4'], label='pH_new_4')
# plt.plot(df['pH_new_.5'], label='pH_new_.5')
# plt.legend()

# %%
# =============================================================================
# กำหนดตัวแปรที่ต้องการใช้ train ตัว model
# =============================================================================

data = df.filter(['ec'])
dataset = data.values

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
# =============================================================================
# MinMaxScaler
# =============================================================================

scaler = MinMaxScaler(feature_range=(0,1))
scaler = scaler.fit(dataset)
dataset_scaled = scaler.transform(dataset)

# dataset_scaled = scaler.fit_transform(dataset)

# %%
n_future = 24
n_past = 48

# %%
import math

train_set_len = math.ceil(len(dataset) * 0.80)
valid_set_len = math.ceil(len(dataset) * 0.10)

# # first 3yrs
# train_set_len = 26280

# # last year
# valid_set_len = 17544

# %%
train_set = dataset_scaled[0:train_set_len, :]

x_train = []
y_train = []

for i in range(n_past, len(train_set) - n_future + 1):
    x_train.append(train_set[i - n_past:i, 0:dataset.shape[1]])
    y_train.append(train_set[i:i + n_future, 0])

# %%
x_train, y_train = np.array(x_train), np.array(y_train)
y_train = np.reshape(y_train, (y_train.shape[0], y_train.shape[1], 1))

# %%
valid_set = dataset_scaled[train_set_len - n_past:train_set_len + valid_set_len, :]

x_valid = []
y_valid = []

for i in range(n_past, len(valid_set) - n_future + 1):
    x_valid.append(valid_set[i - n_past:i, 0:dataset.shape[1]])
    y_valid.append(valid_set[i:i + n_future, 0])

# %%
x_valid, y_valid = np.array(x_valid), np.array(y_valid)
y_valid = np.reshape(y_valid, (y_valid.shape[0], y_valid.shape[1], 1))

# %%
test_set = dataset_scaled[(train_set_len + valid_set_len) - n_past:, :]
test_real = dataset[(train_set_len + valid_set_len) - n_past:, :]

x_test = []
y_test = []

for i in range(n_past, len(test_set) - n_future + 1):
    x_test.append(test_set[i - n_past:i, 0:dataset.shape[1]])
    y_test.append(test_real[i:i + n_future, 0])

# %%
x_test, y_test = np.array(x_test), np.array(y_test)
y_test = np.reshape(y_test, (y_test.shape[0], y_test.shape[1], 1))

# %%
plt.figure(figsize=(16,8))
plt.title('Displays Train set, Validation set, and Test set.')
plt.xlabel('Date')
plt.ylabel('EC')
plt.plot(df[0:train_set_len]["ec"], label='Train')
plt.plot(df[train_set_len - n_past:train_set_len + valid_set_len]["ec"], label='Validation')
plt.plot(df[(train_set_len + valid_set_len) - n_past:]["ec"], label='Test')
plt.legend()
plt.show()

# %%
from keras import Model
from keras.models import Sequential
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import SimpleRNN
from keras.layers import LSTM
# from keras.layers import CuDNNLSTM
from keras.layers import Bidirectional
# from tensorflow.keras.layers import Bidirectional
from keras.optimizers import Adam, SGD, RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# =============================================================================
# Bidirectional LSTM
# =============================================================================

model = Sequential()
model.add(Bidirectional(LSTM(192, return_sequences=True), input_shape=(x_train.shape[1],x_train.shape[2])))
# model.add(Bidirectional(LSTM(96, return_sequences=True)))
model.add(Bidirectional(LSTM(192, return_sequences=False)))
model.add(Dense(n_future))

# model.add(Dense(16))
# model.add(Dense(1))

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 48, 384)          297984
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 384)              886272
#  nal)
#
#  dense (Dense)               (None, 24)                9240
#
# =================================================================
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 48, 384)          297984
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 384)              886272
#  nal)
#
#  dense (Dense)               (None, 24)                9240
#
# =================================================================
# Total params: 1,193,496
# Trainable params: 1,193,496
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=20)

# %%
# checkpoint_filepath = 'checkpoint/lstm-meter-24-3-2-1-gpu-batch-24.h5'
checkpoint_filepath = 'checkpoint/bilstm-24-2022-batch-24.h5'
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_freq='epoch',
    verbose=1
    )

# %%
model_fit = model.fit(
    x_train,
    y_train,
    batch_size=24,
    epochs=128,
    validation_data=(x_valid, y_valid),
    callbacks=[model_checkpoint_callback, early_stopping_callback]
    )
# Out:
# Epoch 1/128
# 290/290 [==============================] - ETA: 0s - loss: 0.0026 - mse: 0.0026
# Epoch 1: val_loss improved from inf to 0.00002, saving model to checkpoint\bilstm-24-2022-batch-24.h5
# 290/290 [==============================] - 65s 197ms/step - loss: 0.0026 - mse: 0.0026 - val_loss:
# Epoch 41/128
# 290/290 [==============================] - ETA: 0s - loss: 2.4099e-04 - mse: 2.4099e-04
# Epoch 41: val_loss did not improve from 0.00001
# 290/290 [==============================] - 124s 428ms/step - loss: 2.4099e-04 - mse: 2.4099e-04 - val_loss: 6.0978e-06 - val_mse: 6.0978e-06
# Epoch 42/128
# 290/290 [==============================] - ETA: 0s - loss: 2.3554e-04 - mse: 2.3554e-04
# Epoch 42: val_loss did not improve from 0.00001
# 290/290 [==============================] - 126s 433ms/step - loss: 2.3554e-04 - mse: 2.3554e-04 - val_loss: 5.1239e-06 - val_mse: 5.1239e-06
# Epoch 43/128
# 290/290 [==============================] - ETA: 0s - loss: 2.4163e-04 - mse: 2.4163e-04
# Epoch 43: val_loss did not improve from 0.00001
# 290/290 [==============================] - 126s 435ms/step - loss: 2.4163e-04 - mse: 2.4163e-04 - val_loss: 9.8068e-06 - val_mse: 9.8068e-06
# Epoch 44/128
# 290/290 [==============================] - ETA: 0s - loss: 2.2674e-04 - mse: 2.2674e-04
# Epoch 44: val_loss did not improve from 0.00001
# 290/290 [==============================] - 129s 444ms/step - loss: 2.2674e-04 - mse: 2.2674e-04 - val_loss: 1.7946e-05 - val_mse: 1.7946e-05
# Epoch 45/128
# 290/290 [==============================] - ETA: 0s - loss: 2.7600e-04 - mse: 2.7600e-04
# Epoch 45: val_loss improved from 0.00001 to 0.00000, saving model to checkpoint\bilstm-24-2022-batch-24.h5
# 290/290 [==============================] - 125s 432ms/step - loss: 2.7600e-04 - mse: 2.7600e-04 - val_loss: 4.3092e-06 - val_mse: 4.3092e-06
# Epoch 46/128
# 290/290 [==============================] - ETA: 0s - loss: 2.0429e-04 - mse: 2.0429e-04
# Epoch 46: val_loss did not improve from 0.00000
# 290/290 [==============================] - 126s 434ms/step - loss: 2.0429e-04 - mse: 2.0429e-04 - val_loss: 9.7908e-06 - val_mse: 9.7908e-06
# Epoch 47/128
# 290/290 [==============================] - ETA: 0s - loss: 2.1680e-04 - mse: 2.1680e-04
# Epoch 47: val_loss improved from 0.00000 to 0.00000, saving model to checkpoint\bilstm-24-2022-batch-24.h5
# 290/290 [==============================] - 125s 431ms/step - loss: 2.1680e-04 - mse: 2.1680e-04 - val_loss: 3.5497e-06 - val_mse: 3.5497e-06
# Epoch 48/128
# 290/290 [==============================] - ETA: 0s - loss: 2.6538e-04 - mse: 2.6538e-04
# Epoch 48: val_loss did not improve from 0.00000
# 290/290 [==============================] - 128s 440ms/step - loss: 2.6538e-04 - mse: 2.6538e-04 - val_loss: 8.4485e-06 - val_mse: 8.4485e-06
# Epoch 49/128
# 290/290 [==============================] - ETA: 0s - loss: 1.9226e-04 - mse: 1.9226e-04
# Epoch 49: val_loss did not improve from 0.00000
# 290/290 [==============================] - 128s 441ms/step - loss: 1.9226e-04 - mse: 1.9226e-04 - val_loss: 3.9265e-06 - val_mse: 3.9265e-06
# Epoch 50/128
# 290/290 [==============================] - ETA: 0s - loss: 1.8717e-04 - mse: 1.8717e-04
# Epoch 50: val_loss did not improve from 0.00000
# 290/290 [==============================] - 129s 444ms/step - loss: 1.8717e-04 - mse: 1.8717e-04 - val_loss: 1.0863e-05 - val_mse: 1.0863e-05
# Epoch 51/128
# 290/290 [==============================] - ETA: 0s - loss: 1.9172e-04 - mse: 1.9172e-04
# Epoch 51: val_loss did not improve from 0.00000
# 290/290 [==============================] - 125s 431ms/step - loss: 1.9172e-04 - mse: 1.9172e-04 - val_loss: 2.4895e-05 - val_mse: 2.4895e-05
# Epoch 52/128
# 290/290 [==============================] - ETA: 0s - loss: 2.0499e-04 - mse: 2.0499e-04
# Epoch 52: val_loss did not improve from 0.00000
# 290/290 [==============================] - 125s 432ms/step - loss: 2.0499e-04 - mse: 2.0499e-04 - val_loss: 2.3625e-05 - val_mse: 2.3625e-05
# Epoch 53/128
# 290/290 [==============================] - ETA: 0s - loss: 2.0906e-04 - mse: 2.0906e-04
# Epoch 53: val_loss improved from 0.00000 to 0.00000, saving model to checkpoint\bilstm-24-2022-batch-24.h5
# 290/290 [==============================] - 123s 424ms/step - loss: 2.0906e-04 - mse: 2.0906e-04 - val_loss: 2.2284e-06 - val_mse: 2.2284e-06
# Epoch 54/128
# 290/290 [==============================] - ETA: 0s - loss: 1.7623e-04 - mse: 1.7623e-04
# Epoch 54: val_loss did not improve from 0.00000
# 290/290 [==============================] - 131s 453ms/step - loss: 1.7623e-04 - mse: 1.7623e-04 - val_loss: 1.0887e-05 - val_mse: 1.0887e-05
# Epoch 55/128
# 290/290 [==============================] - ETA: 0s - loss: 1.6275e-04 - mse: 1.6275e-04
# Epoch 55: val_loss did not improve from 0.00000
# 290/290 [==============================] - 130s 447ms/step - loss: 1.6275e-04 - mse: 1.6275e-04 - val_loss: 1.6589e-05 - val_mse: 1.6589e-05
# Epoch 56/128
# 290/290 [==============================] - ETA: 0s - loss: 1.6365e-04 - mse: 1.6365e-04
# Epoch 56: val_loss did not improve from 0.00000
# 290/290 [==============================] - 60s 208ms/step - loss: 1.6365e-04 - mse: 1.6365e-04 - val_loss: 1.9982e-05 - val_mse: 1.9982e-05
# Epoch 57/128
# 290/290 [==============================] - ETA: 0s - loss: 1.5675e-04 - mse: 1.5675e-04
# Epoch 57: val_loss did not improve from 0.00000
# 290/290 [==============================] - 57s 196ms/step - loss: 1.5675e-04 - mse: 1.5675e-04 - val_loss: 4.6438e-06 - val_mse: 4.6438e-06
# Epoch 58/128
# 290/290 [==============================] - ETA: 0s - loss: 1.4975e-04 - mse: 1.4975e-04
# Epoch 58: val_loss did not improve from 0.00000
# 290/290 [==============================] - 60s 208ms/step - loss: 1.4975e-04 - mse: 1.4975e-04 - val_loss: 2.8400e-06 - val_mse: 2.8400e-06
# Epoch 59/128
# 290/290 [==============================] - ETA: 0s - loss: 1.4664e-04 - mse: 1.4664e-04
# Epoch 59: val_loss did not improve from 0.00000
# 290/290 [==============================] - 60s 205ms/step - loss: 1.4664e-04 - mse: 1.4664e-04 - val_loss: 1.2880e-05 - val_mse: 1.2880e-05
# Epoch 60/128
# 290/290 [==============================] - ETA: 0s - loss: 1.6444e-04 - mse: 1.6444e-04
# Epoch 60: val_loss did not improve from 0.00000
# 290/290 [==============================] - 60s 206ms/step - loss: 1.6444e-04 - mse: 1.6444e-04 - val_loss: 1.2619e-05 - val_mse: 1.2619e-05
# Epoch 61/128
# 290/290 [==============================] - ETA: 0s - loss: 1.3310e-04 - mse: 1.3310e-04
# Epoch 61: val_loss did not improve from 0.00000
# 290/290 [==============================] - 57s 195ms/step - loss: 1.3310e-04 - mse: 1.3310e-04 - val_loss: 2.6978e-06 - val_mse: 2.6978e-06
# Epoch 62/128
# 290/290 [==============================] - ETA: 0s - loss: 1.4570e-04 - mse: 1.4570e-04
# Epoch 62: val_loss did not improve from 0.00000
# 290/290 [==============================] - 59s 203ms/step - loss: 1.4570e-04 - mse: 1.4570e-04 - val_loss: 2.0593e-05 - val_mse: 2.0593e-05
# Epoch 63/128
# 290/290 [==============================] - ETA: 0s - loss: 1.2808e-04 - mse: 1.2808e-04
# Epoch 63: val_loss did not improve from 0.00000
# 290/290 [==============================] - 60s 208ms/step - loss: 1.2808e-04 - mse: 1.2808e-04 - val_loss: 8.0767e-06 - val_mse: 8.0767e-06
# Epoch 64/128
# 290/290 [==============================] - ETA: 0s - loss: 1.2377e-04 - mse: 1.2377e-04
# Epoch 64: val_loss did not improve from 0.00000
# 290/290 [==============================] - 60s 206ms/step - loss: 1.2377e-04 - mse: 1.2377e-04 - val_loss: 3.0262e-06 - val_mse: 3.0262e-06
# Epoch 65/128
# 290/290 [==============================] - ETA: 0s - loss: 1.2818e-04 - mse: 1.2818e-04
# Epoch 65: val_loss did not improve from 0.00000
# 290/290 [==============================] - 59s 203ms/step - loss: 1.2818e-04 - mse: 1.2818e-04 - val_loss: 6.9532e-06 - val_mse: 6.9532e-06
# Epoch 66/128
# 290/290 [==============================] - ETA: 0s - loss: 1.2123e-04 - mse: 1.2123e-04
# Epoch 66: val_loss did not improve from 0.00000
# 290/290 [==============================] - 64s 219ms/step - loss: 1.2123e-04 - mse: 1.2123e-04 - val_loss: 2.5177e-06 - val_mse: 2.5177e-06
# Epoch 67/128
# 290/290 [==============================] - ETA: 0s - loss: 1.1110e-04 - mse: 1.1110e-04
# Epoch 67: val_loss did not improve from 0.00000
# 290/290 [==============================] - 63s 217ms/step - loss: 1.1110e-04 - mse: 1.1110e-04 - val_loss: 1.0536e-05 - val_mse: 1.0536e-05
# Epoch 68/128
# 290/290 [==============================] - ETA: 0s - loss: 1.1395e-04 - mse: 1.1395e-04
# Epoch 68: val_loss did not improve from 0.00000
# 290/290 [==============================] - 62s 215ms/step - loss: 1.1395e-04 - mse: 1.1395e-04 - val_loss: 1.2637e-05 - val_mse: 1.2637e-05
# Epoch 69/128
# 290/290 [==============================] - ETA: 0s - loss: 1.1227e-04 - mse: 1.1227e-04
# Epoch 69: val_loss did not improve from 0.00000
# 290/290 [==============================] - 63s 217ms/step - loss: 1.1227e-04 - mse: 1.1227e-04 - val_loss: 2.1209e-05 - val_mse: 2.1209e-05
# Epoch 70/128
# 290/290 [==============================] - ETA: 0s - loss: 1.3067e-04 - mse: 1.3067e-04
# Epoch 70: val_loss improved from 0.00000 to 0.00000, saving model to checkpoint\bilstm-24-2022-batch-24.h5
# 290/290 [==============================] - 63s 218ms/step - loss: 1.3067e-04 - mse: 1.3067e-04 - val_loss: 2.2142e-06 - val_mse: 2.2142e-06
# Epoch 71/128
# 290/290 [==============================] - ETA: 0s - loss: 1.1221e-04 - mse: 1.1221e-04
# Epoch 71: val_loss did not improve from 0.00000
# 290/290 [==============================] - 59s 204ms/step - loss: 1.1221e-04 - mse: 1.1221e-04 - val_loss: 7.9503e-06 - val_mse: 7.9503e-06
# Epoch 72/128
# 290/290 [==============================] - ETA: 0s - loss: 1.0089e-04 - mse: 1.0089e-04
# Epoch 72: val_loss did not improve from 0.00000
# 290/290 [==============================] - 59s 202ms/step - loss: 1.0089e-04 - mse: 1.0089e-04 - val_loss: 7.2365e-06 - val_mse: 7.2365e-06
# Epoch 73/128
# 290/290 [==============================] - ETA: 0s - loss: 9.7177e-05 - mse: 9.7177e-05
# Epoch 73: val_loss improved from 0.00000 to 0.00000, saving model to checkpoint\bilstm-24-2022-batch-24.h5
# 290/290 [==============================] - 58s 202ms/step - loss: 9.7177e-05 - mse: 9.7177e-05 - val_loss: 2.1721e-06 - val_mse: 2.1721e-06
# Epoch 74/128
# 290/290 [==============================] - ETA: 0s - loss: 9.2247e-05 - mse: 9.2247e-05
# Epoch 74: val_loss did not improve from 0.00000
# 290/290 [==============================] - 57s 198ms/step - loss: 9.2247e-05 - mse: 9.2247e-05 - val_loss: 6.6519e-06 - val_mse: 6.6519e-06
# Epoch 75/128
# 290/290 [==============================] - ETA: 0s - loss: 1.0763e-04 - mse: 1.0763e-04
# Epoch 75: val_loss did not improve from 0.00000
# 290/290 [==============================] - 59s 203ms/step - loss: 1.0763e-04 - mse: 1.0763e-04 - val_loss: 2.5416e-06 - val_mse: 2.5416e-06
# Epoch 76/128
# 290/290 [==============================] - ETA: 0s - loss: 8.6699e-05 - mse: 8.6699e-05
# Epoch 76: val_loss improved from 0.00000 to 0.00000, saving model to checkpoint\bilstm-24-2022-batch-24.h5
# 290/290 [==============================] - 58s 199ms/step - loss: 8.6699e-05 - mse: 8.6699e-05 - val_loss: 1.8906e-06 - val_mse: 1.8906e-06
# Epoch 77/128
# 290/290 [==============================] - ETA: 0s - loss: 8.6255e-05 - mse: 8.6255e-05
# Epoch 77: val_loss did not improve from 0.00000
# 290/290 [==============================] - 58s 198ms/step - loss: 8.6255e-05 - mse: 8.6255e-05 - val_loss: 4.6196e-06 - val_mse: 4.6196e-06
# Epoch 78/128
# 290/290 [==============================] - ETA: 0s - loss: 8.3869e-05 - mse: 8.3869e-05
# 290/290 [==============================] - ETA: 0s - loss: 9.4453e-05 - mse: 9.4453e-05
# Epoch 88: val_loss did not improve from 0.00000
# 290/290 [==============================] - 59s 202ms/step - loss: 9.4453e-05 - mse: 9.4453e-05 - val_loss: 3.0484e-06 - val_mse: 3.0484e-06
# Epoch 89/128
# 290/290 [==============================] - ETA: 0s - loss: 7.1081e-05 - mse: 7.1081e-05
# Epoch 89: val_loss did not improve from 0.00000
# 290/290 [==============================] - 61s 210ms/step - loss: 7.1081e-05 - mse: 7.1081e-05 - val_loss: 7.1378e-06 - val_mse: 7.1378e-06
# Epoch 90/128
# 290/290 [==============================] - ETA: 0s - loss: 8.8097e-05 - mse: 8.8097e-05
# Epoch 90: val_loss did not improve from 0.00000
# 290/290 [==============================] - 62s 215ms/step - loss: 8.8097e-05 - mse: 8.8097e-05 - val_loss: 4.6123e-06 - val_mse: 4.6123e-06
# Epoch 91/128
# 290/290 [==============================] - ETA: 0s - loss: 1.4009e-04 - mse: 1.4009e-04
# Epoch 91: val_loss did not improve from 0.00000
# 290/290 [==============================] - 63s 218ms/step - loss: 1.4009e-04 - mse: 1.4009e-04 - val_loss: 6.5402e-06 - val_mse: 6.5402e-06
# Epoch 92/128
# 290/290 [==============================] - ETA: 0s - loss: 6.5824e-05 - mse: 6.5824e-05
# Epoch 92: val_loss did not improve from 0.00000
# 290/290 [==============================] - 61s 210ms/step - loss: 6.5824e-05 - mse: 6.5824e-05 - val_loss: 2.1714e-06 - val_mse: 2.1714e-06
# Epoch 93/128
# 290/290 [==============================] - ETA: 0s - loss: 6.0959e-05 - mse: 6.0959e-05
# Epoch 93: val_loss did not improve from 0.00000
# 290/290 [==============================] - 61s 212ms/step - loss: 6.0959e-05 - mse: 6.0959e-05 - val_loss: 2.1749e-06 - val_mse: 2.1749e-06
# Epoch 94/128
# 290/290 [==============================] - ETA: 0s - loss: 6.9421e-05 - mse: 6.9421e-05
# Epoch 94: val_loss did not improve from 0.00000
# 290/290 [==============================] - 64s 221ms/step - loss: 6.9421e-05 - mse: 6.9421e-05 - val_loss: 5.6633e-06 - val_mse: 5.6633e-06
# Epoch 95/128
# 290/290 [==============================] - ETA: 0s - loss: 6.1449e-05 - mse: 6.1449e-05
# Epoch 95: val_loss did not improve from 0.00000
# 290/290 [==============================] - 65s 226ms/step - loss: 6.1449e-05 - mse: 6.1449e-05 - val_loss: 1.3128e-05 - val_mse: 1.3128e-05
# Epoch 96/128
# 290/290 [==============================] - ETA: 0s - loss: 5.8272e-05 - mse: 5.8272e-05
# Epoch 96: val_loss improved from 0.00000 to 0.00000, saving model to checkpoint\bilstm-24-2022-batch-24.h5
# 290/290 [==============================] - 69s 238ms/step - loss: 5.8272e-05 - mse: 5.8272e-05 - val_loss: 1.7707e-06 - val_mse: 1.7707e-06
# Epoch 97/128
# 290/290 [==============================] - ETA: 0s - loss: 6.3478e-05 - mse: 6.3478e-05
# Epoch 97: val_loss did not improve from 0.00000
# Epoch 107: val_loss did not improve from 0.00000
# 290/290 [==============================] - 62s 213ms/step - loss: 5.1736e-05 - mse: 5.1736e-05 - val_loss: 3.2988e-06 - val_mse: 3.2988e-06
# Epoch 108/128
# 290/290 [==============================] - ETA: 0s - loss: 5.6090e-05 - mse: 5.6090e-05
# Epoch 108: val_loss did not improve from 0.00000
# 290/290 [==============================] - 64s 221ms/step - loss: 5.6090e-05 - mse: 5.6090e-05 - val_loss: 4.4295e-06 - val_mse: 4.4295e-06
# Epoch 109/128
# 290/290 [==============================] - ETA: 0s - loss: 5.2504e-05 - mse: 5.2504e-05
# Epoch 109: val_loss did not improve from 0.00000
# 290/290 [==============================] - 60s 208ms/step - loss: 5.2504e-05 - mse: 5.2504e-05 - val_loss: 1.0623e-05 - val_mse: 1.0623e-05
# Epoch 110/128
# 290/290 [==============================] - ETA: 0s - loss: 6.6519e-05 - mse: 6.6519e-05
# Epoch 110: val_loss did not improve from 0.00000
# 290/290 [==============================] - 59s 205ms/step - loss: 6.6519e-05 - mse: 6.6519e-05 - val_loss: 2.7356e-06 - val_mse: 2.7356e-06
# Epoch 111/128
# 290/290 [==============================] - ETA: 0s - loss: 5.4551e-05 - mse: 5.4551e-05
# Epoch 111: val_loss did not improve from 0.00000
# 290/290 [==============================] - 58s 201ms/step - loss: 5.4551e-05 - mse: 5.4551e-05 - val_loss: 2.4149e-06 - val_mse: 2.4149e-06
# Epoch 112/128
# 290/290 [==============================] - ETA: 0s - loss: 5.3475e-05 - mse: 5.3475e-05
# Epoch 112: val_loss did not improve from 0.00000
# 290/290 [==============================] - 59s 204ms/step - loss: 5.3475e-05 - mse: 5.3475e-05 - val_loss: 1.0761e-05 - val_mse: 1.0761e-05
# Epoch 113/128
# 290/290 [==============================] - ETA: 0s - loss: 9.8234e-05 - mse: 9.8234e-05
# Epoch 113: val_loss did not improve from 0.00000
# 290/290 [==============================] - 60s 208ms/step - loss: 9.8234e-05 - mse: 9.8234e-05 - val_loss: 5.1614e-06 - val_mse: 5.1614e-06
# Epoch 114/128
# 290/290 [==============================] - ETA: 0s - loss: 4.4823e-05 - mse: 4.4823e-05
# Epoch 114: val_loss did not improve from 0.00000
# 290/290 [==============================] - 63s 217ms/step - loss: 4.4823e-05 - mse: 4.4823e-05 - val_loss: 2.6404e-06 - val_mse: 2.6404e-06
# Epoch 115/128
# 290/290 [==============================] - ETA: 0s - loss: 4.5791e-05 - mse: 4.5791e-05
# Epoch 115: val_loss did not improve from 0.00000
# 290/290 [==============================] - 61s 211ms/step - loss: 4.5791e-05 - mse: 4.5791e-05 - val_loss: 1.5724e-05 - val_mse: 1.5724e-05
# Epoch 116/128
# 290/290 [==============================] - ETA: 0s - loss: 4.7565e-05 - mse: 4.7565e-05
# Epoch 116: val_loss did not improve from 0.00000
# 290/290 [==============================] - 60s 206ms/step - loss: 4.7565e-05 - mse: 4.7565e-05 - val_loss: 3.1759e-06 - val_mse: 3.1759e-06

# %%
plt.figure(figsize=(16,8))
plt.title('LSTM: loss rate')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(model_fit.history['loss'], label='Training loss')
plt.plot(model_fit.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()


# #%%
# from keras.models import load_model

# model = load_model('checkpoint/01-bilstm-24-3-2-1.h5')

# #%%
# pred = model.predict(x_test)

# #%%
# if dataset.shape[1] > 1:
#     pred = np.repeat(pred, dataset.shape[1], axis=-1)

# #%%
# y_pred = scaler.inverse_transform(pred)[:,0]

# #%%
# y_pred = np.reshape(y_pred, (y_pred.shape[0], 1))

# #%%
# from sklearn.metrics import mean_squared_error

# rmse = mean_squared_error(y_test, y_pred, squared=False)
# print(f'RMSE of Bi-LSTM = {rmse}')            

# #%%
# # rmse = np.sqrt(np.mean(np.square((y_test - y_pred))))
# # print(rmse)

# #%%
# rmspe = (np.sqrt(np.mean(np.square((y_test - y_pred) / y_test)))) * 100
# print(f'RMSPE of Bi-LSTM = {rmspe}')


# #%%
# df_compare = pd.DataFrame({'Actual EC':df['ec_corrected'][train_set_len + valid_set_len:]})
# df_compare['Predicted EC'] = y_pred

# #%%
# plt.figure(figsize=(16,8))
# plt.title('Displays Actual EC vs. Predicted EC.')
# plt.xlabel('Date')
# plt.ylabel('Value')
# plt.plot(df_compare['Actual EC'], label='Actual')
# plt.plot(df_compare['Predicted EC'], label='Predicted')
# plt.legend()
# plt.show()

# #%%
# plt.figure(figsize=(16,8))
# plt.title('Displays All Actual EC vs. Predicted EC.')
# plt.xlabel('Date')
# plt.ylabel('Value')
# plt.plot(df['ec_new_.5'], label='All Actual EC')
# plt.plot(df_compare['Predicted EC'], label='Predicted')
# plt.legend()
# plt.show()

# %%
from keras.models import load_model

model = load_model('checkpoint/bilstm-24-2022-batch-24.h5')

# %%
pred = model.predict(x_test)
# Out:
# 27/27 [==============================] - 3s 65ms/step

# %%
rpred = None

# %%
for i in range(pred.shape[1]):
    tpred = pred[:,i]
    tpred = np.reshape(tpred, (tpred.shape[0], 1))
    tpred = np.repeat(tpred, dataset.shape[1], axis=-1)
    tpred = scaler.inverse_transform(tpred)[:,0]
    tpred = np.reshape(tpred, (tpred.shape[0], 1))
    if rpred is None:
        rpred = tpred
    else:
        rpred = np.append(rpred, tpred, axis=1)

# %%
y_pred = rpred[:,0]
y_pred = np.reshape(y_pred, (y_pred.shape[0], 1))

# %%
y_test = np.reshape(y_test, (y_test.shape[0], y_test.shape[1]))

# %%
y_real = y_test[:,0]
y_real = np.reshape(y_real, (y_real.shape[0], 1))

# %%
plt.figure(figsize=(16,8))
plt.title('Bi-LSTM')
plt.plot(y_real, label='y_real')
plt.plot(y_pred, label='y_pred')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error

rmse = mean_squared_error(y_test, rpred, squared=False)
print("RMSE =",rmse)
# Out:
# RMSE = 27.035990442052128

# %%
from sklearn.metrics import mean_absolute_percentage_error

# calculate MAPE
mape = mean_absolute_percentage_error(y_test, rpred)
print(f'MAPE = {mape}')
# Out:
# MAPE = 0.06423763726787383
