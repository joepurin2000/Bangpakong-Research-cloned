# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'Angsana New'
rcParams.update({'font.size': 22})
rcParams['axes.unicode_minus'] = False

# %%
df_sp_05_2019 = pd.read_csv('data/chol-sp05-bangkhanak-2019-hourly-corrected.csv', parse_dates=["datetime"])
df_sp_05_2022 = pd.read_csv('data/chol-sp05-bangkhanak-2022-hourly-corrected.csv', parse_dates=["datetime"])
df_sp_06 = pd.read_csv('data/chol-sp06-bangkrajed-2021-2022-hourly.csv', parse_dates=["datetime"])
df_sp_07 = pd.read_csv('data/chol-sp07-bangkhla-corrected-2017-2022-hourly.csv', parse_dates=["datetime"])
df_sp_08 = pd.read_csv('data/chol-sp08-chachoengsao-2020-2022-hourly-corrected.csv', parse_dates=["datetime"])
df_sp_09 = pd.read_csv("data/chol-sp09-cholcha-2021-2022-hourly-corrected.csv", parse_dates=["datetime"])
df_sp_10 = pd.read_csv('data/chol-sp10-bangpakong-2021-2022-hourly-corrected.csv', parse_dates=["datetime"])

# %%
df_05_2019 = df_sp_05_2019.loc[df_sp_05_2019["datetime"].dt.hour == 6]
df_05_2022 = df_sp_05_2022.loc[df_sp_05_2022["datetime"].dt.hour == 6]

df_06 = df_sp_06.loc[df_sp_06["datetime"].dt.hour == 6]
df_06_to_2021 = df_sp_06.loc[(df_sp_06["datetime"].dt.hour == 6) & (df_sp_06["datetime"].dt.year<=2021)]
df_06_2022 = df_sp_06.loc[(df_sp_06["datetime"].dt.hour == 6) & (df_sp_06["datetime"].dt.year==2022)]

df_07 = df_sp_07.loc[(df_sp_07["datetime"].dt.hour == 6) & (df_sp_07["datetime"].dt.year==2022)]

df_08 = df_sp_08.loc[df_sp_08["datetime"].dt.hour == 6]
df_08_to_2021 = df_sp_08.loc[(df_sp_08["datetime"].dt.hour == 6) & (df_sp_08["datetime"].dt.year <= 2021)]
df_08_2022 = df_sp_08.loc[(df_sp_08["datetime"].dt.hour == 6) & (df_sp_08["datetime"].dt.year == 2022)]

df_09 = df_sp_09.loc[(df_sp_09["datetime"].dt.hour == 6)]
df_09_train = df_09.loc[(df_09["datetime"].dt.year<2022)]
df_09_val = df_09.loc[(df_09["datetime"].dt.year==2022)]

df_10 = df_sp_10.loc[df_sp_10["datetime"].dt.hour == 6]

# %%
df_05_2019[["ec"]].plot(title="SP05-2019")
df_05_2022[["ec"]].plot(title="SP05-2022")

# df_06[["ec"]].plot(title="SP06")
df_06_to_2021[["ec"]].plot(title="SP06-until 2021")
df_06_2022[["ec"]].plot(title="SP06-2022")

df_07[["ec"]].plot(title="SP07")

# df_08[["ec"]].plot(title="SP08")
df_08_to_2021[["ec"]].plot(title="SP08-until 2021")
df_08_2022[["ec"]].plot(title="SP08-2022")

df_09[["ec"]].plot(title="SP09")
# df_09_train[["ec"]].plot(title="SP09_train")
# df_09_val[["ec"]].plot(title="SP09_val")

df_10[["ec"]].plot(title="SP10")
# Out:
# <Axes: title={'center': 'SP10'}>

# %%
"""
train: 10 9 8<=2021 6 5=2019 5=2022
val: 7
test: 8=2022
"""
# Out:
# '\ntrain: 10 9 8<=2021 6 5=2019 5=2022\nval: 7\ntest: 8=2022\n'

# %%
for df in [
            df_05_2019,
           df_05_2022,
           df_06,
           df_06_to_2021,
           df_06_2022,
           df_07,
           df_08,
           df_08_to_2021,
           df_08_2022,
           df_09,
           df_10
           ]:
    df = df.set_index(pd.DatetimeIndex(df["datetime"])).drop(["datetime"], axis=1)

# %%
# # =============================================================================
# # Define the variables you want to use to train the model.
# # =============================================================================

#
dataset_05_2019 = df_05_2019.filter(["ec"]).values
dataset_05_2022 = df_05_2022.filter(["ec"]).values

dataset_06 = df_06.filter(["ec"]).values
dataset_06_to_2021 = df_06_to_2021.filter(["ec"]).values
dataset_06_2022 = df_06_2022.filter(["ec"]).values

dataset_07 = df_07.filter(["ec"]).values

dataset_08 = df_08.filter(["ec"]).values
dataset_08_to_2021 = df_08_to_2021.filter(["ec"]).values
dataset_08_2022 = df_08_2022.filter(["ec"]).values

dataset_09 = df_09.filter(["ec"]).values
dataset_09_train = df_09_train.filter(["ec"]).values
dataset_09_val = df_09_val.filter(["ec"]).values

dataset_10 = df_10.filter(["ec"]).values

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
# =============================================================================
# MinMaxScaler
# =============================================================================

# scaler = StandardScaler()
scaler = MinMaxScaler()
scaler.fit(np.concatenate([
                            dataset_05_2019,
                           dataset_05_2022,
                           dataset_06,
                           dataset_07,
                           dataset_08,
                           dataset_09,
                           dataset_10
                           ]))
# scaler.fit(np.concatenate([
#                            dataset_06,
#                            dataset_07,
#                            dataset_08
#                            ]))

dataset_05_2019_scaled = scaler.transform(dataset_05_2019)
dataset_05_2022_scaled = scaler.transform(dataset_05_2022)

dataset_06_scaled = scaler.transform(dataset_06)
dataset_06_to_2021_scaled = scaler.transform(dataset_06_to_2021)
dataset_06_2022_scaled = scaler.transform(dataset_06_2022)

dataset_07_scaled = scaler.transform(dataset_07)

dataset_08_scaled = scaler.transform(dataset_08)
dataset_08_to_2021_scaled = scaler.transform(dataset_08_to_2021)
dataset_08_2022_scaled = scaler.transform(dataset_08_2022)

dataset_09_scaled = scaler.transform(dataset_09)
dataset_09_train_scaled = scaler.transform(dataset_09_train)
dataset_09_val_scaled = scaler.transform(dataset_09_val)

dataset_10_scaled = scaler.transform(dataset_10)

# %%
n_future = 14
n_past = 28

# n_future = 7
# n_past = 14

# %%
# # =============================================================================
# # Test set (for multiple output)
# # =============================================================================    

test_set = dataset_08_2022_scaled
test_real = dataset_08_2022

x_test = []
y_test = []

for i in range(n_past, len(test_set) - n_future + 1):
    x_test.append(test_set[i - n_past:i, 0:dataset_07.shape[1]])
    y_test.append(test_real[i:i + n_future, 0])

x_test, y_test = np.array(x_test), np.array(y_test)
y_test = np.reshape(y_test, (y_test.shape[0], y_test.shape[1], 1))

# %%
# =============================================================================
# Train set (for multiple datasets)
# =============================================================================

datasets_train = [dataset_10_scaled,
                  dataset_09_scaled,
                  dataset_08_to_2021_scaled,
                  dataset_06_scaled,
                  dataset_05_2019_scaled,
                  dataset_05_2022_scaled
                  ]
# datasets_train = [dataset_08_to_2021_scaled,
#                   dataset_06_to_2021_scaled
#                   ]

x_train = []
y_train = []

for dataset in datasets_train:
    
    train_set = dataset

    for i in range(n_past, len(train_set) - n_future + 1):
        x_train.append(train_set[i - n_past:i, 0:dataset.shape[1]])
        y_train.append(train_set[i:i + n_future, 0])

x_train, y_train = np.array(x_train), np.array(y_train)
y_train = np.reshape(y_train, (y_train.shape[0], y_train.shape[1], 1))

# %%
# =============================================================================
# Validation set (for multiple datasets)
# =============================================================================

datasets = [dataset_07_scaled]

x_valid = []
y_valid = []

for dataset in datasets:
    
    valid_set = dataset

    for i in range(n_past, len(valid_set) - n_future + 1):
        x_valid.append(valid_set[i - n_past:i, 0:dataset.shape[1]])
        y_valid.append(valid_set[i:i + n_future, 0])

x_valid, y_valid = np.array(x_valid), np.array(y_valid)
y_valid = np.reshape(y_valid, (y_valid.shape[0], y_valid.shape[1], 1))

# %%
from keras import Model
from keras.models import Sequential
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import SimpleRNN
from keras.layers import LSTM
# from keras.layers import CuDNNLSTM
from keras.layers import Bidirectional
# from tensorflow.keras.layers import Bidirectional
from keras.optimizers import Adam, SGD, RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# =============================================================================
# Bidirectional LSTM
# =============================================================================

model = Sequential()
model.add(Bidirectional(LSTM(140, return_sequences=True), input_shape=(x_train.shape[1],x_train.shape[2])))
model.add(Bidirectional(LSTM(140,return_sequences=False)))
# model.add(Dense(n_future))
model.add(Dense(n_future,activation='relu'))

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 28, 280)          159040
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 280)              471520
#  nal)
#
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 28, 280)          159040
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 280)              471520
#  nal)
#
#  dense (Dense)               (None, 14)                3934
#
# =================================================================
# Total params: 634,494
# Trainable params: 634,494
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=20)

# %%
# Renamed model
checkpoint_filepath = 'checkpoint/bilstm-14-sp-[10-9-8_to2021-6-5_2019-5_2022]-[7]-[8_2022]-140x2-batch-30-relu_at_output.h5'
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_freq='epoch',
    verbose=1
    )

# %%
model_fit = model.fit(
    x_train,
    y_train,
    batch_size=30,
    epochs=128,
    validation_data=(x_valid, y_valid),
    callbacks=[model_checkpoint_callback, early_stopping_callback]
    )
# Out:
# Epoch 1/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0119 - mse: 0.0119
# Epoch 1: val_loss improved from inf to 0.00101, saving model to checkpoint\bilstm-14-sp-[10-9-8_to2021-6-5_2019-5_2022]-[7]-[8]-140x2-batch-30-relu_at_output.h5
# 114/114 [==============================] - 31s 226ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 2/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0073 - mse: 0.0073
# Epoch 2: val_loss improved from 0.00101 to 0.00099, saving model to checkpoint\bilstm-14-sp-[10-9-8_to2021-6-5_2019-5_2022]-[7]-[8]-140x2-batch-30-relu_at_output.h5
# 114/114 [==============================] - 18s 159ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 9.9455e-04 - val_mse: 9.9455e-04
# Epoch 3/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0066 - mse: 0.0066
# Epoch 3: val_loss improved from 0.00099 to 0.00098, saving model to checkpoint\bilstm-14-sp-[10-9-8_to2021-6-5_2019-5_2022]-[7]-[8]-140x2-batch-30-relu_at_output.h5
# 114/114 [==============================] - 19s 168ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 9.8150e-04 - val_mse: 9.8150e-04
# Epoch 4/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0062 - mse: 0.0062
# Epoch 4: val_loss improved from 0.00098 to 0.00086, saving model to checkpoint\bilstm-14-sp-[10-9-8_to2021-6-5_2019-5_2022]-[7]-[8]-140x2-batch-30-relu_at_output.h5
# 114/114 [==============================] - 20s 178ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 8.6141e-04 - val_mse: 8.6141e-04
# Epoch 5/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0060 - mse: 0.0060
# Epoch 5: val_loss did not improve from 0.00086
# 114/114 [==============================] - 21s 186ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 9.2939e-04 - val_mse: 9.2939e-04
# Epoch 6/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0054 - mse: 0.0054
# Epoch 6: val_loss improved from 0.00086 to 0.00064, saving model to checkpoint\bilstm-14-sp-[10-9-8_to2021-6-5_2019-5_2022]-[7]-[8]-140x2-batch-30-relu_at_output.h5
# 114/114 [==============================] - 22s 191ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 6.4322e-04 - val_mse: 6.4322e-04
# Epoch 7/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0055 - mse: 0.0055
# Epoch 7: val_loss did not improve from 0.00064
# 114/114 [==============================] - 20s 178ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 8.4525e-04 - val_mse: 8.4525e-04
# Epoch 8/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0052 - mse: 0.0052
# Epoch 8: val_loss did not improve from 0.00064
# 114/114 [==============================] - 21s 189ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 6.7916e-04 - val_mse: 6.7916e-04
# Epoch 9/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0050 - mse: 0.0050
# Epoch 9: val_loss did not improve from 0.00064
# 114/114 [==============================] - 21s 184ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 8.2892e-04 - val_mse: 8.2892e-04
# Epoch 10/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0050 - mse: 0.0050
# Epoch 10: val_loss did not improve from 0.00064
# 114/114 [==============================] - 22s 193ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 6.9109e-04 - val_mse: 6.9109e-04
# Epoch 11/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0047 - mse: 0.0047
# Epoch 11: val_loss did not improve from 0.00064
# 114/114 [==============================] - 21s 187ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 8.3287e-04 - val_mse: 8.3287e-04
# Epoch 12/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0047 - mse: 0.0047
# Epoch 12: val_loss did not improve from 0.00064
# 114/114 [==============================] - 21s 188ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 9.9788e-04 - val_mse: 9.9788e-04
# Epoch 13/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0048 - mse: 0.0048
# Epoch 13: val_loss improved from 0.00064 to 0.00061, saving model to checkpoint\bilstm-14-sp-[10-9-8_to2021-6-5_2019-5_2022]-[7]-[8]-140x2-batch-30-relu_at_output.h5
# 114/114 [==============================] - 21s 184ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 6.1391e-04 - val_mse: 6.1391e-04
# Epoch 14/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0045 - mse: 0.0045
# Epoch 14: val_loss improved from 0.00061 to 0.00049, saving model to checkpoint\bilstm-14-sp-[10-9-8_to2021-6-5_2019-5_2022]-[7]-[8]-140x2-batch-30-relu_at_output.h5
# 114/114 [==============================] - 21s 183ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 4.9357e-04 - val_mse: 4.9357e-04
# Epoch 15/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0043 - mse: 0.0043
# Epoch 15: val_loss did not improve from 0.00049
# 114/114 [==============================] - 21s 184ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 5.8650e-04 - val_mse: 5.8650e-04
# Epoch 16/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0041 - mse: 0.0041
# Epoch 16: val_loss did not improve from 0.00049
# 114/114 [==============================] - 21s 187ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 5.6973e-04 - val_mse: 5.6973e-04
# Epoch 17/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0041 - mse: 0.0041
# Epoch 17: val_loss did not improve from 0.00049
# 114/114 [==============================] - 21s 181ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 6.6107e-04 - val_mse: 6.6107e-04
# Epoch 18/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0042 - mse: 0.0042
# Epoch 18: val_loss improved from 0.00049 to 0.00047, saving model to checkpoint\bilstm-14-sp-[10-9-8_to2021-6-5_2019-5_2022]-[7]-[8]-140x2-batch-30-relu_at_output.h5
# 114/114 [==============================] - 20s 177ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 4.6635e-04 - val_mse: 4.6635e-04
# Epoch 19/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0039 - mse: 0.0039
# Epoch 19: val_loss did not improve from 0.00047
# 114/114 [==============================] - 21s 181ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 5.0262e-04 - val_mse: 5.0262e-04
# Epoch 20/128
# 113/114 [============================>.] - ETA: 0s - loss: 0.0038 - mse: 0.0038
# Epoch 20: val_loss did not improve from 0.00047
# 114/114 [==============================] - 14s 119ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 4.6827e-04 - val_mse: 4.6827e-04
# Epoch 21/128
# 113/114 [============================>.] - ETA: 0s - loss: 0.0038 - mse: 0.0038
# Epoch 21: val_loss did not improve from 0.00047
# 114/114 [==============================] - 12s 109ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 4.7901e-04 - val_mse: 4.7901e-04
# Epoch 22/128
# 113/114 [============================>.] - ETA: 0s - loss: 0.0036 - mse: 0.0036
# Epoch 22: val_loss did not improve from 0.00047
# 114/114 [==============================] - 11s 101ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 6.6288e-04 - val_mse: 6.6288e-04
# Epoch 23/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0036 - mse: 0.0036
# Epoch 23: val_loss improved from 0.00047 to 0.00045, saving model to checkpoint\bilstm-14-sp-[10-9-8_to2021-6-5_2019-5_2022]-[7]-[8]-140x2-batch-30-relu_at_output.h5
# 114/114 [==============================] - 13s 113ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 4.4904e-04 - val_mse: 4.4904e-04
# Epoch 24/128
# 113/114 [============================>.] - ETA: 0s - loss: 0.0034 - mse: 0.0034
# Epoch 24: val_loss did not improve from 0.00045
# 114/114 [==============================] - 12s 102ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 7.0675e-04 - val_mse: 7.0675e-04
# Epoch 25/128
# 113/114 [============================>.] - ETA: 0s - loss: 0.0033 - mse: 0.0033
# Epoch 25: val_loss did not improve from 0.00045
# 114/114 [==============================] - 12s 105ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 5.7230e-04 - val_mse: 5.7230e-04
# Epoch 26/128
# 113/114 [============================>.] - ETA: 0s - loss: 0.0032 - mse: 0.0032
# Epoch 26: val_loss improved from 0.00045 to 0.00044, saving model to checkpoint\bilstm-14-sp-[10-9-8_to2021-6-5_2019-5_2022]-[7]-[8]-140x2-batch-30-relu_at_output.h5
# 114/114 [==============================] - 12s 105ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 4.4150e-04 - val_mse: 4.4150e-04
# Epoch 27/128
# 113/114 [============================>.] - ETA: 0s - loss: 0.0032 - mse: 0.0032
# Epoch 27: val_loss did not improve from 0.00044
# 114/114 [==============================] - 12s 105ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 5.7228e-04 - val_mse: 5.7228e-04
# Epoch 28/128
# 113/114 [============================>.] - ETA: 0s - loss: 0.0031 - mse: 0.0031
# Epoch 28: val_loss did not improve from 0.00044
# 114/114 [==============================] - 12s 102ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 5.4175e-04 - val_mse: 5.4175e-04
# Epoch 29/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0032 - mse: 0.0032
# Epoch 29: val_loss did not improve from 0.00044
# 114/114 [==============================] - 12s 104ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 5.4320e-04 - val_mse: 5.4320e-04
# Epoch 30/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0031 - mse: 0.0031
# Epoch 30: val_loss did not improve from 0.00044
# 114/114 [==============================] - 12s 110ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 5.3981e-04 - val_mse: 5.3981e-04
# Epoch 31/128
# 113/114 [============================>.] - ETA: 0s - loss: 0.0028 - mse: 0.0028
# Epoch 31: val_loss did not improve from 0.00044
# 114/114 [==============================] - 13s 116ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 5.0175e-04 - val_mse: 5.0175e-04
# Epoch 32/128
# 113/114 [============================>.] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 32: val_loss did not improve from 0.00044
# 114/114 [==============================] - 11s 100ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 5.1206e-04 - val_mse: 5.1206e-04
# Epoch 33/128
# 113/114 [============================>.] - ETA: 0s - loss: 0.0027 - mse: 0.0027
# Epoch 33: val_loss did not improve from 0.00044
# 114/114 [==============================] - 12s 104ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 4.4576e-04 - val_mse: 4.4576e-04
# Epoch 34/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0026 - mse: 0.0026
# Epoch 34: val_loss did not improve from 0.00044
# 114/114 [==============================] - 12s 108ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 4.9606e-04 - val_mse: 4.9606e-04
# Epoch 35/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 35: val_loss did not improve from 0.00044
# 114/114 [==============================] - 12s 103ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 4.5905e-04 - val_mse: 4.5905e-04
# Epoch 36/128
# 113/114 [============================>.] - ETA: 0s - loss: 0.0026 - mse: 0.0026
# Epoch 36: val_loss did not improve from 0.00044
# 114/114 [==============================] - 12s 103ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 4.8974e-04 - val_mse: 4.8974e-04
# Epoch 37/128
# 113/114 [============================>.] - ETA: 0s - loss: 0.0030 - mse: 0.0030
# Epoch 37: val_loss did not improve from 0.00044
# 114/114 [==============================] - 12s 101ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 5.0941e-04 - val_mse: 5.0941e-04
# Epoch 38/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0025 - mse: 0.0025
# Epoch 38: val_loss did not improve from 0.00044
# 114/114 [==============================] - 11s 94ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 5.0040e-04 - val_mse: 5.0040e-04
# Epoch 39/128
# 113/114 [============================>.] - ETA: 0s - loss: 0.0024 - mse: 0.0024
# Epoch 39: val_loss did not improve from 0.00044
# 114/114 [==============================] - 11s 96ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 5.1298e-04 - val_mse: 5.1298e-04
# Epoch 40/128
# 113/114 [============================>.] - ETA: 0s - loss: 0.0024 - mse: 0.0024
# Epoch 40: val_loss did not improve from 0.00044
# 114/114 [==============================] - 11s 98ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 5.4854e-04 - val_mse: 5.4854e-04
# Epoch 41/128
# 113/114 [============================>.] - ETA: 0s - loss: 0.0022 - mse: 0.0022
# Epoch 41: val_loss did not improve from 0.00044
# 114/114 [==============================] - 11s 98ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 4.7912e-04 - val_mse: 4.7912e-04
# Epoch 42/128
# 113/114 [============================>.] - ETA: 0s - loss: 0.0023 - mse: 0.0023
# Epoch 42: val_loss did not improve from 0.00044
# 114/114 [==============================] - 12s 101ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 4.7927e-04 - val_mse: 4.7927e-04
# Epoch 43/128
# 113/114 [============================>.] - ETA: 0s - loss: 0.0021 - mse: 0.0021
# Epoch 43: val_loss did not improve from 0.00044
# 114/114 [==============================] - 11s 96ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 4.7694e-04 - val_mse: 4.7694e-04
# Epoch 44/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0023 - mse: 0.0023
# Epoch 44: val_loss did not improve from 0.00044
# 114/114 [==============================] - 12s 101ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 7.5148e-04 - val_mse: 7.5148e-04
# Epoch 45/128
# 114/114 [==============================] - ETA: 0s - loss: 0.0021 - mse: 0.0021
# Epoch 45: val_loss did not improve from 0.00044
# 114/114 [==============================] - 12s 101ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 6.4882e-04 - val_mse: 6.4882e-04
# Epoch 46/128
# 113/114 [============================>.] - ETA: 0s - loss: 0.0020 - mse: 0.0020
# Epoch 46: val_loss did not improve from 0.00044
# 114/114 [==============================] - 12s 104ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 6.6791e-04 - val_mse: 6.6791e-04

# %%
plt.figure(figsize=(16,8))
plt.title('Bi-LSTM: loss rate.')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(model_fit.history['loss'], label='Training loss')
plt.plot(model_fit.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# %%
from keras.models import load_model

# model = load_model('checkpoint/bilstm-14-sp-[10-9-8-6_to2021-5_2019-5_2022]-[8_2022]-[7]-140x2-batch-30-relu_at_output.h5')
model = load_model(checkpoint_filepath)

# %%
pred = model.predict(x_test)
# Out:
# 11/11 [==============================] - 1s 21ms/step

# %%
r_pred = None

# %%
dataset_test = np.concatenate([dataset_08_2022])

# %%
for i in range(pred.shape[1]):
    t_pred = pred[:,i]
    t_pred = np.reshape(t_pred, (t_pred.shape[0], 1))
    t_pred = np.repeat(t_pred, dataset_test.shape[1], axis=-1)
    t_pred = scaler.inverse_transform(t_pred)[:,0]
    t_pred = np.reshape(t_pred, (t_pred.shape[0], 1))
    if r_pred is None:
        r_pred = t_pred
    else:
        r_pred = np.append(r_pred, t_pred, axis=1)

# %%
y_test = np.reshape(y_test, (y_test.shape[0], y_test.shape[1]))

# %%
from sklearn.metrics import mean_squared_error

rmse = mean_squared_error(y_test, r_pred, squared=False)
print("RMSE =",rmse)
# Out:
# RMSE = 1851.1071564951073

# %%
from sklearn.metrics import mean_absolute_percentage_error

# calculate MAPE
mape = mean_absolute_percentage_error(y_test, r_pred)
print(f'MAPE = {mape}')
# Out:
# MAPE = 0.580970998589736

# %%
# =============================================================================
# Calculate the Loss Function of each Timestep.
# =============================================================================

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error

for i in range(r_pred.shape[1]):
    y_pred = r_pred[:,i]
    y_pred = np.reshape(y_pred, (y_pred.shape[0], 1))
    y_real = y_test[:,i]
    y_real = np.reshape(y_real, (y_real.shape[0], 1))
    rmse = mean_squared_error(y_real, y_pred, squared=False)
    mape = mean_absolute_percentage_error(y_real, y_pred)
    print(f'Calculate the loss function of Timestep t+{i+1}.')
    print(f'• RMSE of Timestep t+{i+1} = {rmse}')
    print(f'• MAPE of Timestep t+{i+1} = {mape}')
    print('')
# Out:
# Calculate the loss function of Timestep t+1.
# • RMSE of Timestep t+1 = 608.8030279246241
# • MAPE of Timestep t+1 = 0.4138304980759551
#
# Calculate the loss function of Timestep t+2.
# • RMSE of Timestep t+2 = 875.337053223074
# • MAPE of Timestep t+2 = 0.3173471493783093
#
# Calculate the loss function of Timestep t+3.
# • RMSE of Timestep t+3 = 1159.7136050730185
# • MAPE of Timestep t+3 = 0.7525684315982771
#
# Calculate the loss function of Timestep t+4.
# • RMSE of Timestep t+4 = 1314.6658415025206
# • MAPE of Timestep t+4 = 0.6514744455456415
#
# Calculate the loss function of Timestep t+5.
# • RMSE of Timestep t+5 = 1571.6285571627209
# • MAPE of Timestep t+5 = 0.6534451122390637
#
# Calculate the loss function of Timestep t+6.
# • RMSE of Timestep t+6 = 1688.1093088924515
# • MAPE of Timestep t+6 = 0.4600680457096489
#
# Calculate the loss function of Timestep t+7.
# • RMSE of Timestep t+7 = 1997.6756492892562
# • MAPE of Timestep t+7 = 0.5829232711899369
#
# Calculate the loss function of Timestep t+8.
# • RMSE of Timestep t+8 = 2087.65365173816
# • MAPE of Timestep t+8 = 0.5923800923561017
#
# Calculate the loss function of Timestep t+9.
# • RMSE of Timestep t+9 = 2228.1891826117053
# • MAPE of Timestep t+9 = 0.5629747034784416
#
# Calculate the loss function of Timestep t+10.
# • RMSE of Timestep t+10 = 2338.575213588053
# • MAPE of Timestep t+10 = 0.3752444448007076
#
# Calculate the loss function of Timestep t+11.
# • RMSE of Timestep t+11 = 2459.5453257295267
# • MAPE of Timestep t+11 = 0.49436285203392255
#
# Calculate the loss function of Timestep t+12.
# • RMSE of Timestep t+12 = 2523.4225926957283
# • MAPE of Timestep t+12 = 0.6304661467124371
#
# Calculate the loss function of Timestep t+13.
# • RMSE of Timestep t+13 = 2530.718560869158
# • MAPE of Timestep t+13 = 0.7342117511468497
#
# Calculate the loss function of Timestep t+14.
# • RMSE of Timestep t+14 = 2531.4626206315156
# • MAPE of Timestep t+14 = 0.9122970359910105

# %%
# =============================================================================
# Create a line graph comparing actual and predicted values for each Timestep.
# =============================================================================

for i in range(r_pred.shape[1]):
    y_pred = r_pred[:,i]
    y_pred = np.reshape(y_pred, (y_pred.shape[0], 1))
    y_real = y_test[:,i]
    y_real = np.reshape(y_real, (y_real.shape[0], 1))
    plt.figure(figsize=(16,8))
    plt.title(f'Timestep t+{i+1}')
    plt.plot(y_real, label='y_real')
    plt.plot(y_pred, label='y_pred')
    plt.legend()
    plt.show()
