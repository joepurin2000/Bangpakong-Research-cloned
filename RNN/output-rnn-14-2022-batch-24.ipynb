# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'Angsana New'
rcParams.update({'font.size': 22})
rcParams['axes.unicode_minus'] = False

# %%
# df_read = pd.read_csv('data/corrected_data.csv')
# df_read = pd.read_csv('data/meter_corrected.csv')
# df_read = pd.read_csv('data/chol-bangkla-corrected-2017-2022-hourly-corrected.csv', parse_dates=["datetime"])
df_read = pd.read_csv('data/chol-bangkla-corrected-2017-2022-hourly.csv', parse_dates=["datetime"])

# %%
df = df_read.copy()
print(df.dtypes)
# Out:
# datetime    datetime64[ns]
# ec                 float64
# dtype: object

# %%
# df = df.loc[df["datetime"].dt.year==2022]
df = df.loc[(df["datetime"].dt.year==2022) & (df["datetime"].dt.hour==6) & (df["datetime"].dt.minute==0)]
df.sort_values(by=['datetime'],inplace=True)
df.reset_index(drop=True,inplace=True)

# %%
# =============================================================================
# กำหนดตัวแปรที่ต้องการใช้ train ตัว model
# =============================================================================

data = df.filter(['ec'])
dataset = data.values

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
# =============================================================================
# MinMaxScaler
# =============================================================================

scaler = MinMaxScaler(feature_range=(0,1))
scaler = scaler.fit(dataset)
dataset_scaled = scaler.transform(dataset)

# dataset_scaled = scaler.fit_transform(dataset)

# %%
# n_future = 24
# n_past = 48
# step = 1

n_future = 14
n_past = 28

# %%
import math

train_set_len = math.ceil(len(dataset) * 0.80)
valid_set_len = math.ceil(len(dataset) * 0.10)

# # first 3yrs
# train_set_len = 26280

# # last year
# valid_set_len = 17544

# %%
train_set = dataset_scaled[0:train_set_len, :]

x_train = []
y_train = []

for i in range(n_past, len(train_set) - n_future + 1):
    x_train.append(train_set[i - n_past:i, 0:dataset.shape[1]])
    y_train.append(train_set[i:i + n_future, 0])

# %%
x_train, y_train = np.array(x_train), np.array(y_train)
y_train = np.reshape(y_train, (y_train.shape[0], y_train.shape[1], 1))

# %%
valid_set = dataset_scaled[train_set_len - n_past:train_set_len + valid_set_len, :]

x_valid = []
y_valid = []

for i in range(n_past, len(valid_set) - n_future + 1):
    x_valid.append(valid_set[i - n_past:i, 0:dataset.shape[1]])
    y_valid.append(valid_set[i:i + n_future, 0])

# %%
x_valid, y_valid = np.array(x_valid), np.array(y_valid)
y_valid = np.reshape(y_valid, (y_valid.shape[0], y_valid.shape[1], 1))

# %%
test_set = dataset_scaled[(train_set_len + valid_set_len) - n_past:, :]
test_real = dataset[(train_set_len + valid_set_len) - n_past:, :]

x_test = []
y_test = []

for i in range(n_past, len(test_set) - n_future + 1):
    x_test.append(test_set[i - n_past:i, 0:dataset.shape[1]])
    y_test.append(test_real[i:i + n_future, 0])

# %%
x_test, y_test = np.array(x_test), np.array(y_test)
y_test = np.reshape(y_test, (y_test.shape[0], y_test.shape[1], 1))

# %%
plt.figure(figsize=(16,8))
plt.title('Displays Train set, Validation set, and Test set.')
plt.xlabel('Date')
plt.ylabel('EC')
plt.plot(df[0:train_set_len]["ec"], label='Train')
plt.plot(df[train_set_len - n_past:train_set_len + valid_set_len]["ec"], label='Validation')
plt.plot(df[(train_set_len + valid_set_len) - n_past:]["ec"], label='Test')
plt.legend()
plt.show()

# %%
from keras import Model
from keras.models import Sequential
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import SimpleRNN
from keras.layers import LSTM
# from keras.layers import CuDNNLSTM
from keras.layers import Bidirectional
# from tensorflow.keras.layers import Bidirectional
from keras.optimizers import Adam, SGD, RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# =============================================================================
# RNN
# =============================================================================

model = Sequential()
model.add(SimpleRNN(192, return_sequences=True, input_shape=(x_train.shape[1],x_train.shape[2])))
# model.add(SimpleRNN(192, return_sequences=True))
model.add(SimpleRNN(192, return_sequences=False))
model.add(Dense(n_future))

# model.add(SimpleRNN(128, return_sequences=True, input_shape=(x_train.shape[1],x_train.shape[2])))
# model.add(SimpleRNN(64, return_sequences=True))
# model.add(SimpleRNN(64, return_sequences=False))
# model.add(Dense(16))
# model.add(Dense(1))

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 28, 192)           37248
#
#  simple_rnn_1 (SimpleRNN)    (None, 192)               73920
#
#  dense (Dense)               (None, 14)                2702
#
# =================================================================
# Total params: 113,870
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 28, 192)           37248
#
#  simple_rnn_1 (SimpleRNN)    (None, 192)               73920
#
#  dense (Dense)               (None, 14)                2702
#
# =================================================================
# Total params: 113,870
# Trainable params: 113,870
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=20)

# %%
# checkpoint_filepath = 'checkpoint/lstm-meter-24-3-2-1-gpu-batch-24.h5'
checkpoint_filepath = 'checkpoint/rnn-14-2022-batch-24.h5'
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_freq='epoch',
    verbose=1
    )

# %%
model_fit = model.fit(
    x_train,
    y_train,
    batch_size=24,
    epochs=128,
    validation_data=(x_valid, y_valid),
    callbacks=[model_checkpoint_callback, early_stopping_callback]
    )
# Out:
# Epoch 1/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0686 - mse: 0.0686
# Epoch 1: val_loss improved from inf to 0.00435, saving model to checkpoint\rnn-14-2022-batch-24.h5
# 11/11 [==============================] - 2s 47ms/step - loss: 0.0625 - mse: 0.0625 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 2/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0133 - mse: 0.0133
# Epoch 2: val_loss improved from 0.00435 to 0.00192, saving model to checkpoint\rnn-14-2022-batch-24.h5
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 3/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0094 - mse: 0.0094
# Epoch 3: val_loss improved from 0.00192 to 0.00074, saving model to checkpoint\rnn-14-2022-batch-24.h5
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0091 - mse: 0.0091 - val_loss: 7.4373e-04 - val_mse: 7.4373e-04
# Epoch 4/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0053 - mse: 0.0053
# Epoch 4: val_loss did not improve from 0.00074
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 9.8252e-04 - val_mse: 9.8252e-04
# Epoch 5/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0048 - mse: 0.0048
# Epoch 5: val_loss did not improve from 0.00074
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 6/128
# 11/11 [==============================] - ETA: 0s - loss: 0.0040 - mse: 0.0040
# Epoch 6: val_loss improved from 0.00074 to 0.00066, saving model to checkpoint\rnn-14-2022-batch-24.h5
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 6.5881e-04 - val_mse: 6.5881e-04
# Epoch 7/128
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0040 - mse: 0.0040
# Epoch 7: val_loss improved from 0.00066 to 0.00023, saving model to checkpoint\rnn-14-2022-batch-24.h5
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 2.2710e-04 - val_mse: 2.2710e-04
# Epoch 8/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0037 - mse: 0.0037
# Epoch 8: val_loss did not improve from 0.00023
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 6.8986e-04 - val_mse: 6.8986e-04
# Epoch 9/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0035 - mse: 0.0035
# Epoch 9: val_loss did not improve from 0.00023
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 5.7800e-04 - val_mse: 5.7800e-04
# Epoch 10/128
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0032 - mse: 0.0032
# Epoch 10: val_loss improved from 0.00023 to 0.00015, saving model to checkpoint\rnn-14-2022-batch-24.h5
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 1.4956e-04 - val_mse: 1.4956e-04
# Epoch 11/128
# 11/11 [==============================] - ETA: 0s - loss: 0.0024 - mse: 0.0024
# Epoch 11: val_loss did not improve from 0.00015
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 12/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0027 - mse: 0.0027
# Epoch 12: val_loss improved from 0.00015 to 0.00009, saving model to checkpoint\rnn-14-2022-batch-24.h5
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 9.0026e-05 - val_mse: 9.0026e-05
# Epoch 13/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0034 - mse: 0.0034
# Epoch 13: val_loss did not improve from 0.00009
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 9.8749e-04 - val_mse: 9.8749e-04
# Epoch 14/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0044 - mse: 0.0044
# Epoch 14: val_loss did not improve from 0.00009
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 6.5502e-04 - val_mse: 6.5502e-04
# Epoch 15/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0064 - mse: 0.0064
# Epoch 15: val_loss did not improve from 0.00009
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 8.1261e-04 - val_mse: 8.1261e-04
# Epoch 16/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0048 - mse: 0.0048
# Epoch 16: val_loss did not improve from 0.00009
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 6.5966e-04 - val_mse: 6.5966e-04
# Epoch 17/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0028 - mse: 0.0028
# Epoch 17: val_loss did not improve from 0.00009
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 3.5911e-04 - val_mse: 3.5911e-04
# Epoch 18/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0024 - mse: 0.0024
# Epoch 18: val_loss did not improve from 0.00009
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 1.6418e-04 - val_mse: 1.6418e-04
# Epoch 19/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0023 - mse: 0.0023
# Epoch 19: val_loss did not improve from 0.00009
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 2.1126e-04 - val_mse: 2.1126e-04
# Epoch 20/128
# 11/11 [==============================] - ETA: 0s - loss: 0.0024 - mse: 0.0024
# Epoch 20: val_loss did not improve from 0.00009
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 4.3328e-04 - val_mse: 4.3328e-04
# Epoch 21/128
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0024 - mse: 0.0024
# Epoch 21: val_loss did not improve from 0.00009
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 3.2334e-04 - val_mse: 3.2334e-04
# Epoch 22/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0032 - mse: 0.0032
# Epoch 22: val_loss did not improve from 0.00009
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 3.4890e-04 - val_mse: 3.4890e-04
# Epoch 23/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0025 - mse: 0.0025
# Epoch 23: val_loss did not improve from 0.00009
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 4.4532e-04 - val_mse: 4.4532e-04
# Epoch 24/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0028 - mse: 0.0028
# Epoch 24: val_loss did not improve from 0.00009
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 1.8065e-04 - val_mse: 1.8065e-04
# Epoch 25/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0029 - mse: 0.0029
# Epoch 25: val_loss did not improve from 0.00009
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 1.1145e-04 - val_mse: 1.1145e-04
# Epoch 26/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0023 - mse: 0.0023
# Epoch 26: val_loss did not improve from 0.00009
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 1.6924e-04 - val_mse: 1.6924e-04
# Epoch 27/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0014 - mse: 0.0014
# Epoch 27: val_loss did not improve from 0.00009
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 1.9234e-04 - val_mse: 1.9234e-04
# Epoch 28/128
# 11/11 [==============================] - ETA: 0s - loss: 0.0017 - mse: 0.0017
# Epoch 28: val_loss did not improve from 0.00009
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 1.0983e-04 - val_mse: 1.0983e-04
# Epoch 29/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0014 - mse: 0.0014
# Epoch 29: val_loss did not improve from 0.00009
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 9.4482e-05 - val_mse: 9.4482e-05
# Epoch 30/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0013 - mse: 0.0013
# Epoch 30: val_loss did not improve from 0.00009
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 1.5645e-04 - val_mse: 1.5645e-04
# Epoch 31/128
# 11/11 [==============================] - ETA: 0s - loss: 0.0013 - mse: 0.0013
# Epoch 31: val_loss did not improve from 0.00009
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 1.7641e-04 - val_mse: 1.7641e-04
# Epoch 32/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0016 - mse: 0.0016
# Epoch 32: val_loss improved from 0.00009 to 0.00007, saving model to checkpoint\rnn-14-2022-batch-24.h5
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 7.1684e-05 - val_mse: 7.1684e-05
# Epoch 33/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0014 - mse: 0.0014
# Epoch 33: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 1.3713e-04 - val_mse: 1.3713e-04
# Epoch 34/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0018 - mse: 0.0018
# Epoch 34: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 2.4259e-04 - val_mse: 2.4259e-04
# Epoch 35/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0016 - mse: 0.0016
# Epoch 35: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 8.0303e-05 - val_mse: 8.0303e-05
# Epoch 36/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0014 - mse: 0.0014
# Epoch 36: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 1.8062e-04 - val_mse: 1.8062e-04
# Epoch 37/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0016 - mse: 0.0016
# Epoch 37: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 4.0869e-04 - val_mse: 4.0869e-04
# Epoch 38/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0021 - mse: 0.0021
# Epoch 38: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 39/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0027 - mse: 0.0027
# Epoch 39: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 2.1276e-04 - val_mse: 2.1276e-04
# Epoch 40/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0016 - mse: 0.0016
# Epoch 40: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 8.9547e-05 - val_mse: 8.9547e-05
# Epoch 41/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0015 - mse: 0.0015
# Epoch 41: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 2.0580e-04 - val_mse: 2.0580e-04
# Epoch 42/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0012 - mse: 0.0012
# Epoch 42: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 1.2037e-04 - val_mse: 1.2037e-04
# Epoch 43/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0010 - mse: 0.0010
# Epoch 43: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 7.7976e-05 - val_mse: 7.7976e-05
# Epoch 44/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0011 - mse: 0.0011
# Epoch 44: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 1.1609e-04 - val_mse: 1.1609e-04
# Epoch 45/128
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0014 - mse: 0.0014
# Epoch 45: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 1.0648e-04 - val_mse: 1.0648e-04
# Epoch 46/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0012 - mse: 0.0012
# Epoch 46: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 1.9584e-04 - val_mse: 1.9584e-04
# Epoch 47/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0012 - mse: 0.0012
# Epoch 47: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 2.4757e-04 - val_mse: 2.4757e-04
# Epoch 48/128
#  8/11 [====================>.........] - ETA: 0s - loss: 9.8053e-04 - mse: 9.8053e-04
# Epoch 48: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 1.1976e-04 - val_mse: 1.1976e-04
# Epoch 49/128
#  8/11 [====================>.........] - ETA: 0s - loss: 6.9767e-04 - mse: 6.9767e-04
# Epoch 49: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 18ms/step - loss: 6.9355e-04 - mse: 6.9355e-04 - val_loss: 7.2524e-05 - val_mse: 7.2524e-05
# Epoch 50/128
#  8/11 [====================>.........] - ETA: 0s - loss: 7.5934e-04 - mse: 7.5934e-04
# Epoch 50: val_loss improved from 0.00007 to 0.00007, saving model to checkpoint\rnn-14-2022-batch-24.h5
# 11/11 [==============================] - 0s 19ms/step - loss: 7.5416e-04 - mse: 7.5416e-04 - val_loss: 6.7095e-05 - val_mse: 6.7095e-05
# Epoch 51/128
# 10/11 [==========================>...] - ETA: 0s - loss: 8.1380e-04 - mse: 8.1380e-04
# Epoch 51: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 16ms/step - loss: 7.9591e-04 - mse: 7.9591e-04 - val_loss: 2.2517e-04 - val_mse: 2.2517e-04
# Epoch 52/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0013 - mse: 0.0013
# Epoch 52: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 2.5121e-04 - val_mse: 2.5121e-04
# Epoch 53/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0010 - mse: 0.0010
# Epoch 53: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 2.3777e-04 - val_mse: 2.3777e-04
# Epoch 54/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0011 - mse: 0.0011
# Epoch 54: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 2.0470e-04 - val_mse: 2.0470e-04
# Epoch 55/128
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0015 - mse: 0.0015
# Epoch 55: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 3.2077e-04 - val_mse: 3.2077e-04
# Epoch 56/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0011 - mse: 0.0011
# Epoch 56: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 1.1620e-04 - val_mse: 1.1620e-04
# Epoch 57/128
#  9/11 [=======================>......] - ETA: 0s - loss: 9.6078e-04 - mse: 9.6078e-04
# Epoch 57: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 2.9341e-04 - val_mse: 2.9341e-04
# Epoch 58/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0019 - mse: 0.0019
# Epoch 58: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 6.0159e-04 - val_mse: 6.0159e-04
# Epoch 59/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0026 - mse: 0.0026
# Epoch 59: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 3.1831e-04 - val_mse: 3.1831e-04
# Epoch 60/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0016 - mse: 0.0016
# Epoch 60: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 4.4332e-04 - val_mse: 4.4332e-04
# Epoch 61/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0010 - mse: 0.0010
# Epoch 61: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 2.6647e-04 - val_mse: 2.6647e-04
# Epoch 62/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0014 - mse: 0.0014
# Epoch 62: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 2.7821e-04 - val_mse: 2.7821e-04
# Epoch 63/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0020 - mse: 0.0020
# Epoch 63: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 2.0392e-04 - val_mse: 2.0392e-04
# Epoch 64/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0015 - mse: 0.0015
# Epoch 64: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 1.6069e-04 - val_mse: 1.6069e-04
# Epoch 65/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0010 - mse: 0.0010
# Epoch 65: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 19ms/step - loss: 9.9093e-04 - mse: 9.9093e-04 - val_loss: 6.9256e-05 - val_mse: 6.9256e-05
# Epoch 66/128
#  9/11 [=======================>......] - ETA: 0s - loss: 7.9260e-04 - mse: 7.9260e-04
# Epoch 66: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 19ms/step - loss: 7.8064e-04 - mse: 7.8064e-04 - val_loss: 8.1554e-05 - val_mse: 8.1554e-05
# Epoch 67/128
# 10/11 [==========================>...] - ETA: 0s - loss: 8.6326e-04 - mse: 8.6326e-04
# Epoch 67: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 16ms/step - loss: 8.4999e-04 - mse: 8.4999e-04 - val_loss: 2.3330e-04 - val_mse: 2.3330e-04
# Epoch 68/128
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0013 - mse: 0.0013
# Epoch 68: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 2.5782e-04 - val_mse: 2.5782e-04
# Epoch 69/128
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0020 - mse: 0.0020
# Epoch 69: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 2.8152e-04 - val_mse: 2.8152e-04
# Epoch 70/128
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0014 - mse: 0.0014
# Epoch 70: val_loss did not improve from 0.00007
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 6.0330e-04 - val_mse: 6.0330e-04

# %%
plt.figure(figsize=(16,8))
plt.title('RNN: loss rate')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(model_fit.history['loss'], label='Training loss')
plt.plot(model_fit.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()


# #%%
# from keras.models import load_model

# model = load_model('checkpoint/01-bilstm-24-3-2-1.h5')

# #%%
# pred = model.predict(x_test)

# #%%
# if dataset.shape[1] > 1:
#     pred = np.repeat(pred, dataset.shape[1], axis=-1)

# #%%
# y_pred = scaler.inverse_transform(pred)[:,0]

# #%%
# y_pred = np.reshape(y_pred, (y_pred.shape[0], 1))

# #%%
# from sklearn.metrics import mean_squared_error

# rmse = mean_squared_error(y_test, y_pred, squared=False)
# print(f'RMSE of Bi-LSTM = {rmse}')            

# #%%
# # rmse = np.sqrt(np.mean(np.square((y_test - y_pred))))
# # print(rmse)

# #%%
# rmspe = (np.sqrt(np.mean(np.square((y_test - y_pred) / y_test)))) * 100
# print(f'RMSPE of Bi-LSTM = {rmspe}')


# #%%
# df_compare = pd.DataFrame({'Actual EC':df['ec_corrected'][train_set_len + valid_set_len:]})
# df_compare['Predicted EC'] = y_pred

# #%%
# plt.figure(figsize=(16,8))
# plt.title('Displays Actual EC vs. Predicted EC.')
# plt.xlabel('Date')
# plt.ylabel('Value')
# plt.plot(df_compare['Actual EC'], label='Actual')
# plt.plot(df_compare['Predicted EC'], label='Predicted')
# plt.legend()
# plt.show()

# #%%
# plt.figure(figsize=(16,8))
# plt.title('Displays All Actual EC vs. Predicted EC.')
# plt.xlabel('Date')
# plt.ylabel('Value')
# plt.plot(df['ec_new_.5'], label='All Actual EC')
# plt.plot(df_compare['Predicted EC'], label='Predicted')
# plt.legend()
# plt.show()

# %%
from keras.models import load_model

model = load_model('checkpoint/rnn-14-2022-batch-24.h5')

# %%
pred = model.predict(x_test)
# Out:
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 213ms/step

# %%
rpred = None

# %%
for i in range(pred.shape[1]):
    tpred = pred[:,i]
    tpred = np.reshape(tpred, (tpred.shape[0], 1))
    tpred = np.repeat(tpred, dataset.shape[1], axis=-1)
    tpred = scaler.inverse_transform(tpred)[:,0]
    tpred = np.reshape(tpred, (tpred.shape[0], 1))
    if rpred is None:
        rpred = tpred
    else:
        rpred = np.append(rpred, tpred, axis=1)

# %%
y_pred = rpred[:,0]
y_pred = np.reshape(y_pred, (y_pred.shape[0], 1))

# %%
y_test = np.reshape(y_test, (y_test.shape[0], y_test.shape[1]))

# %%
y_real = y_test[:,0]
y_real = np.reshape(y_real, (y_real.shape[0], 1))

# %%
plt.figure(figsize=(16,8))
plt.title('RNN')
plt.plot(y_real, label='y_real')
plt.plot(y_pred, label='y_pred')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error

rmse = mean_squared_error(y_test, rpred, squared=False)
print("RMSE =",rmse)
# Out:
# RMSE = 120.32766217647395

# %%
from sklearn.metrics import mean_absolute_percentage_error

# calculate MAPE
mape = mean_absolute_percentage_error(y_test, rpred)
print(f'MAPE = {mape}')
# Out:
# MAPE = 0.33780938552758505
